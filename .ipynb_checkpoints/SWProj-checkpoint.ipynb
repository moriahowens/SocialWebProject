# %% [markdown]
# # Social Web Project | Group 2
# ## Analysis of Gender-Based Hate Speech Towards Female Dutch Politicians in the Most Recent Dutch General Election
# ### by Moriah Owens, Christina Benopoulou, Tzortzina Gianni, and Isabelle Huguetto

# %% [markdown]
# Install Mastodon. If this doesn't work, try !pip3 instead of !pip.

# %%
# !pip install mastodon.py
# Out:
# Requirement already satisfied: mastodon.py in ./lib/python3.12/site-packages (2.1.4)
# Requirement already satisfied: requests>=2.4.2 in ./lib/python3.12/site-packages (from mastodon.py) (2.32.5)
# Requirement already satisfied: python-dateutil in ./lib/python3.12/site-packages (from mastodon.py) (2.9.0.post0)
# Requirement already satisfied: python-magic in ./lib/python3.12/site-packages (from mastodon.py) (0.4.27)
# Requirement already satisfied: decorator>=4.0.0 in ./lib/python3.12/site-packages (from mastodon.py) (5.2.1)
# Requirement already satisfied: blurhash>=1.1.4 in ./lib/python3.12/site-packages (from mastodon.py) (1.1.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./lib/python3.12/site-packages (from requests>=2.4.2->mastodon.py) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in ./lib/python3.12/site-packages (from requests>=2.4.2->mastodon.py) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./lib/python3.12/site-packages (from requests>=2.4.2->mastodon.py) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./lib/python3.12/site-packages (from requests>=2.4.2->mastodon.py) (2025.11.12)
# Requirement already satisfied: six>=1.5 in ./lib/python3.12/site-packages (from python-dateutil->mastodon.py) (1.17.0)
#
# [notice] A new release of pip is available: 23.2.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# Establish connection to Mastodon below.
# You will need to add your own client_id, client_secret, and access_token in order to run Mastodon requests.

# %%
from mastodon import Mastodon

API = Mastodon(
    client_id='AlXEFnh5_DcvCymjl5m9ds32jzY1unQ4l7wiHzuebEc', #Client key
    client_secret='hZlaUilk7K8xvTqYEI4YMiBmiWMhh-cooriVcSTjsRM', #Client secret
    access_token='bd8z8yczTMblqVw3gcW2yZXQGrxnUmFWwW_XW2qFpoI', #Your access token
    api_base_url='https://mastodon.social'  
)

me = API.account_verify_credentials()
print(me)
# If connection has been established correctly, your basic profile information will print below.
# Out:
# Account({'id': 115469282164664965, 'username': 'moriahowens', 'acct': 'moriahowens', 'display_name': '', 'discoverable': None, 'group': False, 'locked': False, 'created_at': datetime.datetime(2025, 10, 31, 0, 0, tzinfo=tzutc()), 'following_count': 0, 'followers_count': 0, 'statuses_count': 5, 'note': '', 'url': 'https://mastodon.social/@moriahowens', 'uri': 'https://mastodon.social/ap/users/115469282164664965', 'avatar': 'https://mastodon.social/avatars/original/missing.png', 'header': 'https://mastodon.social/headers/original/missing.png', 'avatar_static': 'https://mastodon.social/avatars/original/missing.png', 'header_static': 'https://mastodon.social/headers/original/missing.png', 'moved': None, 'suspended': None, 'limited': None, 'bot': False, 'fields': [], 'emojis': [], 'last_status_at': datetime.datetime(2025, 10, 31, 0, 0), 'noindex': False, 'roles': [], 'role': Role({'id': '-99', 'name': '', 'permissions': '65536', 'color': '', 'highlighted': False}), 'source': CredentialAccountSource({'privacy': 'public', 'sensitive': False, 'note': '', 'language': None, 'fields': [], 'follow_requests_count': 0, 'indexable': False, 'hide_collections': None, 'discoverable': None, 'attribution_domains': [], 'quote_policy': 'public'}), 'mute_expires_at': None, 'indexable': False, 'hide_collections': None, 'memorial': None})

# %% [markdown]
# The following cell exists solely for Jupyter Notebook debugging. I can run this cell to determine if the Kernel needs to be restarted.

# %%
1+1
# Out:
# 2

# %% [markdown]
# This block gets all toots on Mastodon that contain the phrase "Dutch election" (or related phases/hashtags) and were created in 2025. It stores the text content of these toots in a list called "toots".

# %%
query = "Dutch election"
toots = []
max_toots = 1000

# Page 1
results = API.search_v2(query)
statuses = results.get("statuses", [])

for s in statuses:
    content = s.get("content", "")
    timestamp = s.get("created_at")

    if timestamp:
        text = content.lower()
        match_phrase1 = "dutch election" in text
        match_phrase2 = "netherlands election" in text
        match_phrase3 = "election in the netherlands" in text
        match_phrase4 = "election in netherlands" in text
        match_phrase5 = "dutch general election" in text
        match_phrase6 = "netherlands general election" in text
        match_hashtag1 = "#dutchelection" in text
        match_hashtag2 = "#netherlandselection" in text
    
    if (match_phrase1 or match_phrase2 or match_phrase3 or match_phrase4 or match_phrase5 or match_phrase6 or match_hashtag1 or match_hashtag2) and timestamp.year == 2025:
        toots.append(content)

print("First page returned", len(statuses), "statuses")

# Next Page(s) if they exist
# search_v2 returns something like results["statuses"][...]["id"]
while len(toots) < max_toots and len(statuses) > 0:
    print("Next page returned", len(statuses), "statuses")
    last_id = statuses[-1]["id"]

    results = API.search_v2(query, max_id=last_id)
    statuses = results.get("statuses", [])

    if not statuses:
        break

    for s in statuses:
        content = s.get("content", "")
        timestamp = s.get("created_at")
        
        if timestamp:
            text = content.lower()
            match_phrase1 = "dutch election" in text
            match_phrase2 = "netherlands election" in text
            match_phrase3 = "election in the netherlands" in text
            match_phrase4 = "election in netherlands" in text
            match_phrase5 = "dutch general election" in text
            match_phrase6 = "netherlands general election" in text
            match_hashtag1 = "#dutchelection" in text
            match_hashtag2 = "#netherlandselection" in text
    
        if (match_phrase1 or match_phrase2 or match_phrase3 or match_phrase4 or match_phrase5 or match_phrase6 or match_hashtag1 or match_hashtag2) and timestamp.year == 2025:
            toots.append(content)


    if timestamp.year < 2025:
        break

        """
        if len(toots) >= max_toots:
            break
        """
for i, t in enumerate(toots[:20]):
    print(t)
# Out:
# First page returned 18 statuses
# Next page returned 18 statuses
# Next page returned 19 statuses
# Next page returned 20 statuses
# Next page returned 15 statuses
# Next page returned 13 statuses
# Next page returned 17 statuses
# Next page returned 18 statuses
# Next page returned 19 statuses
# Next page returned 16 statuses
# Next page returned 17 statuses
# Next page returned 19 statuses
# Next page returned 18 statuses
# Next page returned 17 statuses
# Next page returned 18 statuses
# Next page returned 20 statuses
# Next page returned 20 statuses
# Next page returned 18 statuses
# Next page returned 20 statuses
# Next page returned 18 statuses
# Next page returned 17 statuses
# Next page returned 20 statuses
# Next page returned 17 statuses
# Next page returned 18 statuses
# Next page returned 14 statuses
# Next page returned 17 statuses
# Next page returned 17 statuses
# Next page returned 15 statuses
# Next page returned 15 statuses
# Next page returned 16 statuses
# Next page returned 16 statuses
# Next page returned 18 statuses
# Next page returned 19 statuses
# Next page returned 19 statuses
# Next page returned 17 statuses
# Next page returned 17 statuses
# Next page returned 14 statuses
# Next page returned 18 statuses
# <p>Millennial Leaders Won the Dutch Elections</p><p>A quiet generational shift is transforming politics.</p><p>(<a href="https://archive.ph/x3ss3" target="_blank" rel="nofollow noopener" translate="no"><span class="invisible">https://</span><span class="">archive.ph/x3ss3</span><span class="invisible"></span></a>)</p><p><a href="https://foreignpolicy.com/2025/11/10/netherlands-millennials-politicians-jetten-coalition/" target="_blank" rel="nofollow noopener" translate="no"><span class="invisible">https://</span><span class="ellipsis">foreignpolicy.com/2025/11/10/n</span><span class="invisible">etherlands-millennials-politicians-jetten-coalition/</span></a></p>
# <p>📰 Millennial Leaders Won the Dutch Elections</p><p>🔗 <a href="https://foreignpolicy.com/2025/11/10/netherlands-millennials-politicians-jetten-coalition/" rel="nofollow noopener" translate="no" target="_blank"><span class="invisible">https://</span><span class="ellipsis
class="mention hashtag" rel="nofollow noopener" target="_blank">#<span>politics</span></a> </p><p><a href="https://www.theguardian.com/commentisfree/2025/nov/02/dutch-voters-positivity-liberals-patriotism-d66-netherlands-election" rel="nofollow noopener" translate="no" target="_blank"><span class="invisible">https://www.</span><span class="ellipsis">theguardian.com/commentisfree/</span><span class="invisible">2025/nov/02/dutch-voters-positivity-liberals-patriotism-d66-netherlands-election</span></a></p>
# <p>If you follow me on <a href="https://todon.nl/tags/BlueSky" class="mention hashtag" rel="nofollow noopener" target="_blank">#<span>BlueSky</span></a> I have bad news for you. Tomorrow (Monday) my posts won't appear on BlueSky anymore. I turned Bridgy Fed on for the Dutch elections, but those are now over. So goodbye! 👋🏻</p>
# <p>Don’t be too relieved: Dutch election result not ‘end of populism’ or far-right | EUobserver<br /><a href="https://euobserver.com/eu-elections/ard231c688" target="_blank" rel="nofollow noopener" translate="no"><span class="invisible">https://</span><span class="ellipsis">euobserver.com/eu-elections/ar</span><span class="invisible">d231c688</span></a></p><p><a href="https://mastodon.social/tags/netherlands" class="mention hashtag" rel="tag">#<span>netherlands</span></a></p>
# <p>Rob Jetten, the winner of the Dutch general elections proposes a humane but controlled immigration approach<br /><a href="https://mastodon.social/tags/ImmigrantTimes" class="mention hashtag" rel="tag">#<span>ImmigrantTimes</span></a> <a href="https://mastodon.social/tags/DutchElection" class="mention hashtag" rel="tag">#<span>DutchElection</span></a> <a href="https://mastodon.social/tags/DutchImmigration" class="mention hashtag" rel="tag">#<span>DutchImmigration</span></a><br /><a href="https://www.immigranttimes.org/post/dutch-immigration-controlled-but-humane" target="_blank" rel="nofollow noopener" translate="no"><span class="invisible">https://www.</span><span class="ellipsis">immigranttimes.org/post/dutch-</span><span class="invisible">immigration-controlled-but-humane</span></a></p>
# <p>The Dutch elections, NATO ties, and the race to reduce dependence on US defence <a href="https://www.rfi.fr/en/international/20251101-the-dutch-elections-nato-ties-and-the-race-to-reduce-dependence-on-us-defence" rel="nofollow noopener" translate="no" target="_blank"><span class="invisible">https://www.</span><span class="ellipsis">rfi.fr/en/international/202511</span><span class="invisible">01-the-dutch-elections-nato-ties-and-the-race-to-reduce-dependence-on-us-defence</span></a></p>
# <p>The Dutch election is now finished, and it looks like we'll have a younger gay guy (38) as a prime minister. That's nice! Though he's a centrist, which is not so nice.</p><p>But here's the thing: If their party cannot form a coalition with other parties, there's just elections again. Looks likely!</p>
# <p>I think the Dutch election discussion has to start with everyone understanding that in proportional systems getting first means nothing</p>

# %%
# This is how many toots have been created in 2025 in English about the Dutch general election.
print(len(toots))
# Out:
# 272

# %% [markdown]
# This block does the same, but for toots in Dutch, storing them in the list "dutchtoots"

# %%
dutchquery = "nederlandse verkiezingen"
dutchtoots = []
max_toots = 1000

# Page 1
dutchresults = API.search_v2(dutchquery)
dutchstatuses = dutchresults.get("statuses", [])

for s in dutchstatuses:
    content = s.get("content", "")
    timestamp = s.get("created_at")

    if timestamp:
        text = content.lower()
        match_phrase7 = "nederlandse verkiezingen" in text
        match_phrase8 = "nederlandse algemene verkiezingen" in text
        match_phrase9 = "verkiezingen in Nederland" in text
        match_hashtag3 = "#nederlandseverkiezingen" in text
        match_hashtag4 = "#nederlandsealgemeneverkiezingen" in text

    
    if (match_phrase7 or match_phrase8 or match_phrase9 or match_hashtag3 or match_hashtag4) and timestamp.year == 2025:
        dutchtoots.append(content)

print("First page returned", len(dutchstatuses), "statuses")

# Next Page(s) if they exist
# search_v2 returns something like results["statuses"][...]["id"]
while len(dutchtoots) < max_toots and len(dutchstatuses) > 0:
    print("Next page returned", len(dutchstatuses), "statuses")
    last_id = dutchstatuses[-1]["id"]

    dutchresults = API.search_v2(dutchquery, max_id=last_id)
    dutchstatuses = dutchresults.get("statuses", [])

    if not dutchstatuses:
        break

    for s in dutchstatuses:
        content = s.get("content", "")
        timestamp = s.get("created_at")
        
        if timestamp:
            text = content.lower()
            match_phrase7 = "nederlandse verkiezingen" in text
            match_phrase8 = "nederlandse algemene verkiezingen" in text
            match_phrase9 = "verkiezingen in Nederland" in text
            match_hashtag3 = "#nederlandseverkiezingen" in text
            match_hashtag4 = "#nederlandsealgemeneverkiezingen" in text
    
        if (match_phrase7 or match_phrase8 or match_phrase9 or match_hashtag3 or match_hashtag4) and timestamp.year == 2025:
            dutchtoots.append(content)


    if timestamp.year < 2025:
        break

        """
        if len(toots) >= max_toots:
            break
        """
for i, t in enumerate(dutchtoots[:20]):
    print(t)
# Out:
# First page returned 19 statuses
# Next page returned 19 statuses
# Next page returned 19 statuses
# Next page returned 20 statuses
# Next page returned 20 statuses
# Next page returned 20 statuses
# <p>Russische framing van de Nederlandse verkiezingen: geopolitiek, delegitimatie en mediaspektakel,</p><p>Hoe Russische media onze verkiezingen ombuigen tot een spiegel van Moskou’s eigen wereldbeeld.</p><p><a href="https://www.web-watch.org/news/russische-framing-nederlandse-verkiezingen" rel="nofollow noopener" translate="no" target="_blank"><span class="invisible">https://www.</span><span class="ellipsis">web-watch.org/news/russische-f</span><span class="invisible">raming-nederlandse-verkiezingen</span></a> <a href="https://mastodon.nl/tags/NLpol" class="mention hashtag" rel="nofollow noopener" target="_blank">#<span>NLpol</span></a> <a href="https://mastodon.nl/tags/TK2025" class="mention hashtag" rel="nofollow noopener" target="_blank">#<span>TK2025</span></a> <a href="https://mastodon.nl/tags/verkiezingen" class="mention hashtag" rel="nofollow noopener" target="_blank">#<span>verkiezingen</span></a></p>
# <p>Wat maakt dat koffiedikkijken door extreem-rechts mogelijk?
#
# Allereerst komt dat door de aard van Nederlandse verkiezingen. Door de gehele "democratie" te laten concentreren in één verkiezing elke paar jaar lopen miljoenen dingen door elkaar heen.
#
# <a href="https://www.doorbraak.eu/feedback-in-de-nederlandse-democratie/" rel="nofollow noopener" target="_blank">www.doorbraak.eu/feedback-in-...</a><br><br><a href="https://www.doorbraak.eu/feedback-in-de-nederlandse-democratie/" rel="nofollow noopener" target="_blank">Feedback in de Nederlandse dem...</a></p>
# <p>🎁 Gokautoriteit onderzoekt cryptosite Polymarket na weddenschappen op Nederlandse verkiezingen<br><a href="https://fd.nl/financiele-markten/1576241/gokautoriteit-onderzoekt-cryptosite-polymarket-na-weddenschappen-op-nederlandse-verkiezingen?utm_medium=social&amp;utm_source=app&amp;utm_campaign=earned&amp;utm_content=20251110&amp;utm_term=app-android&amp;gift=zgF4E" rel="nofollow noopener" translate="no" target="_blank"><span class="invisible">https://</span><span class="ellipsis
rel="nofollow noopener" translate="no" target="_blank"><span class="invisible">https://</span><span class="ellipsis">watdoejij.noblogs.org/post/202</span><span class="invisible">5/09/09/plak-mee-tegen-fascisme/</span></a> “De Nederlandse verkiezingen komen eraan en de eerste racistische en fascistische posters (van de FvD) zijn al gesignaleerd. We kunnen niet toestaan dat ze ruimte innemen, niet op straat, niet op muren, nergens. Print deze tegenpropagandaposter gerust zelf in</p>
# <p>Begin oktober kennelijk geen politieke advertenties meer op Facebook, interessant, ook voor de Nederlandse verkiezingen eind oktober, welke partij zou hier het meest last van hebben? (Of maakt het niets uit)<br /><a href="https://about.fb.com/news/2025/07/ending-political-electoral-and-social-issue-advertising-in-the-eu/" target="_blank" rel="nofollow noopener" translate="no"><span class="invisible">https://</span><span class="ellipsis">about.fb.com/news/2025/07/endi</span><span class="invisible">ng-political-electoral-and-social-issue-advertising-in-the-eu/</span></a><br /><a href="https://mastodon.social/tags/politiek" class="mention hashtag" rel="tag">#<span>politiek</span></a> <a href="https://mastodon.social/tags/eu" class="mention hashtag" rel="tag">#<span>eu</span></a> <a href="https://mastodon.social/tags/verkiezingen" class="mention hashtag" rel="tag">#<span>verkiezingen</span></a></p>

# %%
# This is how many toots have been created in 2025 in Dutch about the Dutch general election.
print(len(dutchtoots))
# Out:
# 14

# %% [markdown]
# This block filters the toots we gathered, picking out the toots that reference one of the 64 House of Representatives members that are female.

# %%
totalelectiontoots = toots + dutchtoots

# List of the last names of all female politicians in the House of Representatives
# First name is included where there are multiple politicians with the same last name
# This will be used to gather instances of references to these politicians
female_politicians = ["Abdi", "van Ark", "Armut", "Becker", "Beckerman", "Belhirch", "van Berkel", "Biekman", "Bikker", "Boelsma-Hoekstra", "van Brenk", "Bromet", "Buhler", "Coenradie", "Heera Dijk", "Inge van Dijk", "Dobbe", "van Eijk", "El Boujdaini", "den Hollander", "ten Hove", "Huizenga", "Kathmann", "Keijzer", "Kostic", "Kroger", "Lahlah", "Lammers", "Maeijer", "Martens-America", "van Meetelen", "Michon-Derkzen", "Moinat", "Moorman", "Mutluer", "Oosterhout", "Oualhadj", "Ouwehand", "Patijn", "Paulusma", "Piri", "van der Plas", "Podt", "Raijer", "Rajkowski", "Rooderkerk", "Schilder", "Steen", "Straatman", "Synhaeve", "Teunissen", "Tijmstra", "Tseggai", "Vellinga-Beemsterboer", "Vliegenthart", "Vondeling", "de Vos", "Wendel", "van der Werf", "Westerveld", "Wiersma", "Yesilgoz-Zegerius", "Zalinyan", "Zwinkels"]

electiontootsaboutwomen = []

for t in totalelectiontoots:
    # Does the toot contain a reference to a female politician?
    fem_ref = 0
    for f in female_politicians:
        if f in t:
            fem_ref = 1
    if fem_ref == 1:
        electiontootsaboutwomen.append(t)

print(len(electiontootsaboutwomen))
# Out:
# ['<p>Trending in <a href="https://toot.community/tags/TheNetherlands" class="mention hashtag" rel="nofollow noopener" target="_blank">#<span>TheNetherlands</span></a> on Oct 30, 2025</p><p>Rob Jetten<br>2025 Dutch general election<br>Nicolás Keenan<br>Lidewij de Vos</p><p>Discover more on <a href="https://trendingon.wiki/en/trends/thenetherlands/2025-10-30" rel="nofollow noopener" translate="no" target="_blank"><span class="invisible">https://</span><span class="ellipsis">trendingon.wiki/en/trends/then</span><span class="invisible">etherlands/2025-10-30</span></a></p>', '<p>New paper:</p><p>‘Issue ownership in the online campaign for Dutch general elections: A topic modeling approach.’</p><p>By Joren Vrancken, Tom Dobber, and me. </p><p>Journal of Digital Social Research, open access.</p><p><a href="https://publicera.kb.se/jdsr/article/view/54885" rel="nofollow noopener" translate="no" target="_blank"><span class="invisible">https://</span><span class="ellipsis">publicera.kb.se/jdsr/article/v</span><span class="invisible">iew/54885</span></a></p><p><a href="https://akademienl.social/tags/politics" class="mention hashtag" rel="nofollow noopener" target="_blank">#<span>politics</span></a> <a href="https://akademienl.social/tags/law" class="mention hashtag" rel="nofollow noopener" target="_blank">#<span>law</span></a> <a href="https://akademienl.social/tags/elections" class="mention hashtag" rel="nofollow noopener" target="_blank">#<span>elections</span></a> <a href="https://akademienl.social/tags/netherlands" class="mention hashtag" rel="nofollow noopener" target="_blank">#<span>netherlands</span></a> <a href="https://akademienl.social/tags/microtargeting" class="mention hashtag" rel="nofollow noopener" target="_blank">#<span>microtargeting</span></a> <a href="https://akademienl.social/tags/dsa" class="mention hashtag" rel="nofollow noopener" target="_blank">#<span>dsa</span></a> <a href="https://akademienl.social/tags/tech" class="mention hashtag" rel="nofollow noopener" target="_blank">#<span>tech</span></a> <a href="https://akademienl.social/tags/advertising" class="mention hashtag" rel="nofollow noopener" target="_blank">#<span>advertising</span></a> <a href="https://akademienl.social/tags/meta" class="mention hashtag" rel="nofollow noopener" target="_blank">#<span>meta</span></a> <a href="https://akademienl.social/tags/Facebook" class="mention hashtag" rel="nofollow noopener" target="_blank">#<span>Facebook</span></a></p>']

# %% [markdown]
# There are only 2 toots that reference Dutch female politicians in the toots that we gathered.
#
# This is an indication that either:
# 1. There is simply not enough data available on Mastodon
# 2. Our method of data collection is too narrowing, and we need to go about it a different way
#
# We can continue by attempting to search for toots by the name of the politician first, since any toots that reference the first and last name of any of these politicians (in the year 2025) are extremely likely to be talking about Dutch elections.

# %%
female_pol_firstlast = ["Fatihya Abdi", "Elles van Ark", "Etkin Armut", "Bente Becker", "Sandra Beckerman", "Fatimazhra Belhirch", "Nathalie van Berkel", "Anouschka Biekman", "Mirjam Bikker", "Lucienne Boelsma-Hoekstra", "Corrie van Brenk", "Laura Bromet", "Judith Buhler", "Ingrid Coenradie", "Heera Dijk", "Inge van Dijk", "Sarah Dobbe", "Wendy van Eijk", "Sarah El Boujdaini", "Renate den Hollander", "Tamara ten Hove", "Renilde Huizenga", "Barbara Kathmann", "Mona Keijzer", "Ines Kostic", "Suzanne Kroger", "Esmah Lahlah", "Annelotte Lammers", "Vicky Maeijer", "Claire Martens-America", "Rachel van Meetelen", "Ingrid Michon-Derkzen", "Nicole Moinat", "Marjolein Moorman", "Songul Mutluer", "Annabel Nanninga", "Sjoukje van Oosterhout", "Ouafa Oualhadj", "Esther Ouwehand", "Mariette Patijn", "Wieke Paulusma", "Kati Piri", "Caroline van der Plas", "Anne-Marijke Podt", "Annette Raijer", "Queeny Rajkowski", "Ilana Rooderkerk", "Shanna Schilder", "Hanneke Steen", "Jeltje Straatman", "Marijke Synhaeve", "Christine Teunissen", "Eveline Tijmstra", "Mikal Tseggai", "Marieke Vellinga-Beemsterboer", "Lisa Vliegenthart", "Marina Vondeling", "Lidewij de Vos", "Hilde Wendel", "Hanneke van der Werf", "Lisa Westerveld", "Femke Wiersma", "Dilan Yesilgoz-Zegerius", "Ani Zalinyan", "Jantine Zwinkels"]
print(len(female_pol_firstlast))
# Out:
# 65

# %%
name_toots = []

# Page 1
for name in female_pol_firstlast:
    print("Searching for ", name)
    results = API.search_v2(name)
    statuses = results.get("statuses", [])

    for s in statuses:
        content = s.get("content", "")
        timestamp = s.get("created_at")
        if timestamp.year == 2025:
            name_toots.append({
                "text": content,
                "politician": name,
                "hate_speech": False,
                "hate_categories": []
            })


    print("First page returned", len(statuses), "statuses")

    # Next Page(s) if they exist
    # search_v2 returns something like results["statuses"][...]["id"]
    prev_last_id = None
    while len(statuses) > 0:
        print("Next page returned", len(statuses), "statuses")

        last_id = int(statuses[-1]["id"])
        if last_id == prev_last_id:
            print("Pagination stuck, breaking.")
            break
        prev_last_id = last_id

        results = API.search_v2(name, max_id=str(last_id - 1))
        statuses = results.get("statuses", [])

        if not statuses:
            break

        for s in statuses:
            content = s.get("content", "")
            timestamp = s.get("created_at")
            if timestamp.year == 2025:
                name_toots.append({
                    "text": content,
                    "politician": name,
                    "hate_speech": False,
                    "hate_categories": []
                })


        if timestamp.year < 2025:
            break
# Out:
# Searching for  Fatihya Abdi
# First page returned 4 statuses
# Next page returned 4 statuses
# Searching for  Elles van Ark
# First page returned 3 statuses
# Next page returned 3 statuses
# Searching for  Etkin Armut
# First page returned 1 statuses
# Next page returned 1 statuses
# Next page returned 1 statuses
# Pagination stuck, breaking.
# Searching for  Bente Becker
# First page returned 20 statuses
# Next page returned 20 statuses
# Searching for  Sandra Beckerman
# First page returned 19 statuses
# Next page returned 19 statuses
# Searching for  Fatimazhra Belhirch
# First page returned 2 statuses
# Next page returned 2 statuses
# Next page returned 1 statuses
# Pagination stuck, breaking.
# Searching for  Nathalie van Berkel
# First page returned 6 statuses
# Next page returned 6 statuses
# Next page returned 1 statuses
# Pagination stuck, breaking.
# Searching for  Anouschka Biekman
# First page returned 0 statuses
# Searching for  Mirjam Bikker
# First page returned 20 statuses
# Next page returned 20 statuses
# Searching for  Lucienne Boelsma-Hoekstra
# First page returned 0 statuses
# Searching for  Corrie van Brenk
# First page returned 0 statuses
# Searching for  Laura Bromet
# First page returned 20 statuses
# Next page returned 20 statuses
# Searching for  Judith Buhler
# First page returned 1 statuses
# Next page returned 1 statuses
# Searching for  Ingrid Coenradie
# First page returned 19 statuses
# Next page returned 19 statuses
# Next page returned 20 statuses
# Searching for  Heera Dijk
# First page returned 2 statuses
# Next page returned 2 statuses
# Next page returned 1 statuses
# Pagination stuck, breaking.
# Searching for  Inge van Dijk
# First page returned 10 statuses
# Next page returned 10 statuses
# Searching for  Sarah Dobbe
# First page returned 20 statuses
# Next page returned 20 statuses
# Searching for  Wendy van Eijk
# First page returned 4 statuses
# Next page returned 4 statuses
# Searching for  Sarah El Boujdaini
# First page returned 10 statuses
# Next page returned 10 statuses
# Next page returned 1 statuses
# Pagination stuck, breaking.
# Searching for  Renate den Hollander
# First page returned 1 statuses
# Next page returned 1 statuses
# Next page returned 1 statuses
# Pagination stuck, breaking.
# Searching for  Tamara ten Hove
# First page returned 0 statuses
# Searching for  Renilde Huizenga
# First page returned 0 statuses
# Searching for  Barbara Kathmann
# First page returned 17 statuses
# Next page returned 17 statuses
# Next page returned 17 statuses
# Next page returned 19 statuses
# Next page returned 20 statuses
# Searching for  Mona Keijzer
# First page returned 17 statuses
# Next page returned 17 statuses
# Next page returned 16 statuses
# Next page returned 14 statuses
# Next page returned 20 statuses
# Next page returned 20 statuses
# Next page returned 18 statuses
# Next page returned 20 statuses
# Next page returned 20 statuses
# Next page returned 20 statuses
# Next page returned 18 statuses
# Next page returned 20 statuses
# Next page returned 20 statuses
# Searching for  Ines Kostic
# First page returned 20 statuses
# Next page returned 20 statuses
# Searching for  Suzanne Kroger
# First page returned 20 statuses
# Next page returned 20 statuses
# Searching for  Esmah Lahlah
# First page returned 15 statuses
# Next page returned 15 statuses
# Next page returned 12 statuses
# Searching for  Annelotte Lammers
# First page returned 3 statuses
# Next page returned 3 statuses
# Next page returned 1 statuses
# Pagination stuck, breaking.
# Searching for  Vicky Maeijer
# First page returned 18 statuses
# Next page returned 18 statuses
# Searching for  Claire Martens-America
# First page returned 2 statuses
# Next page returned 2 statuses
# Next page returned 1 statuses
# Pagination stuck, breaking.
# Searching for  Rachel van Meetelen
# First page returned 3 statuses
# Next page returned 3 statuses
# Searching for  Ingrid Michon-Derkzen
# First page returned 7 statuses
# Next page returned 7 statuses
# Searching for  Nicole Moinat
# First page returned 0 statuses
# Searching for  Marjolein Moorman
# First page returned 15 statuses
# Next page returned 15 statuses
# Searching for  Songul Mutluer
# First page returned 8 statuses
# Next page returned 8 statuses
# Searching for  Annabel Nanninga
# First page returned 19 statuses
# Next page returned 19 statuses
# Next page returned 20 statuses
# Searching for  Sjoukje van Oosterhout
# First page returned 1 statuses
# Next page returned 1 statuses
# Next page returned 1 statuses
# Pagination stuck, breaking.
# Searching for  Ouafa Oualhadj
# First page returned 0 statuses
# Searching for  Esther Ouwehand
# First page returned 17 statuses
# Next page returned 17 statuses
# Next page returned 20 statuses
# Next page returned 20 statuses
# Next page returned 18 statuses
# Next page returned 20 statuses
# Next page returned 20 statuses
# Searching for  Mariette Patijn
# First page returned 2 statuses
# Next page returned 2 statuses
# Searching for  Wieke Paulusma
# First page returned 13 statuses
# Next page returned 13 statuses
# Searching for  Kati Piri
# First page returned 19 statuses
# Next page returned 19 statuses
# Next page returned 20 statuses
# Next page returned 20 statuses
# Searching for  Caroline van der Plas
# First page returned 17 statuses
# Next page returned 17 statuses
# Next page returned 17 statuses
# Next page returned 20 statuses
# Next page returned 20 statuses
# Next page returned 20 statuses
# Next page returned 20 statuses
# Next page returned 16 statuses
# Next page returned 17 statuses
# Next page returned 20 statuses
# Next page returned 20 statuses
# Next page returned 20 statuses
# Next page returned 20 statuses
# Searching for  Anne-Marijke Podt
# First page returned 14 statuses
# Next page returned 14 statuses
# Searching for  Annette Raijer
# First page returned 2 statuses
# Next page returned 2 statuses
# Searching for  Queeny Rajkowski
# First page returned 16 statuses
# Next page returned 16 statuses
# Searching for  Ilana Rooderkerk
# First page returned 5 statuses
# Next page returned 5 statuses
# Searching for  Shanna Schilder
# First page returned 4 statuses
# Next page returned 4 statuses
# Next page returned 1 statuses
# Pagination stuck, breaking.
# Searching for  Hanneke Steen
# First page returned 6 statuses
# Next page returned 6 statuses
# Next page returned 1 statuses
# Pagination stuck, breaking.
# Searching for  Jeltje Straatman
# First page returned 1 statuses
# Next page returned 1 statuses
# Next page returned 1 statuses
# Pagination stuck, breaking.
# Searching for  Marijke Synhaeve
# First page returned 1 statuses
# Next page returned 1 statuses
# Searching for  Christine Teunissen
# First page returned 19 statuses
# Next page returned 19 statuses
# Searching for  Eveline Tijmstra
# First page returned 0 statuses
# Searching for  Mikal Tseggai
# First page returned 5 statuses
# Next page returned 5 statuses
# Searching for  Marieke Vellinga-Beemsterboer
# First page returned 3 statuses
# Next page returned 3 statuses
# Searching for  Lisa Vliegenthart
# First page returned 3 statuses
# Next page returned 3 statuses
# Next page returned 1 statuses
# Pagination stuck, breaking.
# Searching for  Marina Vondeling
# First page returned 12 statuses
# Next page returned 12 statuses
# Searching for  Lidewij de Vos
# First page returned 14 statuses
# Next page returned 14 statuses
# Next page returned 19 statuses
# Next page returned 20 statuses
# Next page returned 2 statuses
# Searching for  Hilde Wendel
# First page returned 2 statuses
# Next page returned 2 statuses
# Next page returned 1 statuses
# Pagination stuck, breaking.
# Searching for  Hanneke van der Werf
# First page returned 9 statuses
# Next page returned 9 statuses
# Searching for  Lisa Westerveld
# First page returned 20 statuses
# Next page returned 20 statuses
# Searching for  Femke Wiersma
# First page returned 19 statuses
# Next page returned 19 statuses
# Next page returned 20 statuses
# Next page returned 20 statuses
# Next page returned 20 statuses
# Searching for  Dilan Yesilgoz-Zegerius
# First page returned 19 statuses
# Next page returned 19 statuses
# Searching for  Ani Zalinyan
# First page returned 0 statuses
# Searching for  Jantine Zwinkels
# First page returned 1 statuses
# Next page returned 1 statuses

# %% [markdown]
# Since we now have enough toots, we can analyze them for hate speech. The following code is adapted from the Bluesky file.

# %%
import re

# %%
hate_keywords = {
    'sexist': [
        # English
        'bitch', 'slut', 'whore', 'feminazi', 'should be home', 'kitchen', 
        'belong in kitchen', 'stay home', 'not fit for', 'too emotional',
        'hormonal', 'on her period', 'typical woman', 'like all women',
        'gold digger', 'sleeping her way', 'token woman', 'diversity hire',
        # Dutch
        'hoer', 'slet', 'teef', 'wijf', 'kutwijf', 'trut', 'tuthola',
        'blijf thuis', 'thuishoren', 'keuken', 'niet geschikt',
        'typisch vrouw', 'als alle vrouwen', 'emancipatiehoer'
    ],
    
    'appearance': [
        # English
        'ugly', 'fat', 'old', 'haggard', 'looks like', 'hideous', 'disgusting',
        'needs makeup', 'aging', 'wrinkled', 'unattractive', 'gross', 'obese',
        'pig', 'cow', 'dog', 'horse face', 'too old', 'past her prime',
        'should dress better', 'unfuckable', 'butter face',
        # Dutch
        'lelijk', 'dik', 'oud', 'afgetakeld', 'ziet eruit als', 'goor',
        'walgelijk', 'smerig', 'varken', 'koe', 'hond', 'te oud', 
        'ouwe taart', 'opgespoten', 'plastisch'
    ],
    
    'threats': [
        # English
        'kill', 'rape', 'assault', 'death threat', 'should die', 'hope you die',
        'deserve to die', 'hang', 'shoot', 'stab', 'murder', 'assassinate',
        'violence', 'hurt', 'beat', 'attack', 'lynch', 'burn',
        'going to get', 'coming for you', 'watch your back', 'better watch out',
        # Dutch
        'dood', 'verkracht', 'vermoord', 'doodgeschoten', 'opgehangen',
        'gestoken', 'aanval', 'geweld', 'pijn doen', 'slaan', 'pak op je',
        'krijg je', 'komt ervan', 'kijk maar uit', 'pas maar op'
    ],
    
    'misogyny': [
        # English
        'stupid woman', 'dumb female', 'emotional', 'hysterical', 'irrational',
        'cant think', 'no brain', 'empty head', 'airhead', 'bimbo', 'ditzy',
        'woman logic', 'female brain', 'overly sensitive', 'dramatic',
        'attention seeker', 'attention whore', 'playing victim', 'victim card',
        'women are', 'females are', 'all women', 'typical female',
        # Dutch
        'domme vrouw', 'stomme wijf', 'emotioneel', 'hysterisch', 'irrationeel',
        'geen hersens', 'leeg hoofd', 'dom blondje', 'vrouwenlogica',
        'typisch vrouwelijk', 'aandachtshoer', 'slachtoffer spelen',
        'vrouwen zijn', 'alle vrouwen', 'wijven zijn'
    ],
    
    'objectification': [
        # English
        'hot', 'sexy', 'body', 'breasts', 'legs', 'ass', 'boobs', 'tits',
        'would bang', 'would smash', 'milf', 'piece of ass', 'nice rack',
        'fuckable', 'bangable', 'doable', 'eye candy', 'arm candy',
        'prostitute', 'escort', 'stripper', 'pornstar',
        # Dutch
        'lekker', 'geil', 'lichaam', 'borsten', 'tieten', 'kont', 'benen',
        'neuken', 'pikken', 'pijpen', 'hoer', 'prostituee', 'slet',
        'hoerig', 'sletterig', 'goedkoop'
    ],
    
    'competence_undermining': [
        # English
        'unqualified', 'incompetent', 'clueless', 'has no idea', 'doesnt know',
        'out of her depth', 'in over her head', 'puppet', 'controlled by',
        'token', 'quota', 'affirmative action', 'only there because',
        'diversity', 'check box', 'not earned', 'handed to her',
        # Dutch
        'onbekwaam', 'incompetent', 'geen idee', 'weet niet', 'snapt niet',
        'marionet', 'pop', 'aangestuurd door', 'quotum', 'alleen maar omdat',
        'diversiteit', 'niet verdiend', 'cadeau gekregen'
    ],
    
    'dismissive': [
        # English
        'shut up', 'nobody cares', 'who cares', 'go away', 'disappear',
        'resign', 'step down', 'quit', 'get out', 'fuck off', 'piss off',
        'go back to', 'return to', 'not welcome', 'dont belong',
        # Dutch
        'kop dicht', 'hou je bek', 'bek houden', 'niemand interesseert',
        'boeit niet', 'rot op', 'oprotten', 'wegwezen', 'ga weg',
        'opzouten', 'opdonderen', 'aftreden', 'opstappen', 'ga terug naar',
        'niet welkom', 'hoort hier niet'
    ],
    
    'ethnic_religious_slurs': [
        # English (relevant to Dutch political context)
        'muslim', 'immigrant', 'foreign', 'terrorist', 'go back', 'not dutch',
        'invasion', 'replacement', 'traitor', 'islam lover', 'multiculti',
        # Dutch
        'moslim', 'allochtoon', 'buitenlander', 'terrorist', 'ga terug',
        'niet nederlands', 'invasie', 'vervanging', 'landverraad', 'verrader',
        'islamliefhebber', 'gutmensch', 'linkse rat'
    ]
}
for post in name_toots:
    text_lower = post["text"].lower()
    post['hate_speech'] = False
    post['hate_categories'] = []

    for category, keywords in hate_keywords.items():
        for kw in keywords:
            kw_escaped = re.escape(kw)

            pattern = r'\b' + kw_escaped + r'\b'

            if re.search(pattern, text_lower):
                post['hate_speech'] = True
                post['hate_categories'].append(category)
                break


total = len(name_toots)
hate_count = len([p for p in name_toots if p['hate_speech']])

print(f"Total posts: {total}")
print(f"Posts with potential hate speech: {hate_count} ({hate_count/total*100:.1f}%)")
print(f"\nBreakdown by category:")

for category in hate_keywords.keys():
    count = len([p for p in name_toots if category in p.get('hate_categories', [])])
    print(f"  - {category}: {count}")
# Out:
# Total posts: 1371
# Posts with potential hate speech: 107 (7.8%)
#
# Breakdown by category:
#   - sexist: 8
#   - appearance: 30
#   - threats: 45
#   - misogyny: 4
#   - objectification: 17
#   - competence_undermining: 7
#   - dismissive: 6
#   - ethnic_religious_slurs: 6

# %% [markdown]
# Next, we will do the same process with the male politicians, so that we can compare results.

# %%
male_pols = ["Thierry Aartsen", "Ismail el Abassi", "Robert van Asten", "Stephan van Baarle", "Mpanzu Bamenga", "Thierry Baudet", "Daniel van den Berg", "Harry Bevers", "Henri Botenbal", "Diederik Boomsma", "Maikel Boon", "Martin Bosma", "Derk Boswijk", "Ruben Brekelmans", "Tijs van den Brink", "Bart van den Brink", "Eric van der Burg", "Julian Bushoff", "Thom van Campen", "Don Ceder", "Simon Ceulemans", "Rene Claassen", "Ranjith Clemminck", "Laurens Dassen", "Ralk Dekker", "Tony van Dijck", "Jimmy Dijk", "Emiel van Dijk", "Diederik van Dijk", "Peter van Duijvenvoorde", "Joost Eerdmans", "Ulysse Ellian", "Dogukan Ergin", "Silvio Erkens", "Marjolein Faber", "Andre Flach", "Maarten Goudzwaard", "Dion Graus", "Pieter Grinwis", "Peter de Groot", "Sarath Hamstra", "Eelco Heinen", "Hidde Heutink", "Michiel Hoogeveen", "Habtamu de Hoop", "Pepijn van Houwelingen", "Dion Huidekooper", "Frederik Jansen", "Chris Jansen", "Rob Jetten", "Henk Jumelet", "Vincent Karremans", "Arend Kisteman", "Jesse Klaver", "Felix Klos", "Jan Arie Koorevaar", "Alexander Kops", "Daan de Kort", "Ulas Kose", "Harmen Krul", "Maes van Lanschot", "Tom van der Lee", "Gidi Markuszower", "Gideon van Meijeren", "Mohammed Mohandis", "Jeremy Mooiman", "Edgar Mulder", "Stephen Neijenhuis", "Jurgen Nobel", "Henk-Jan Oosterhuis", "Jan Paternotte", "Erwin Prickaertz", "Raymond de Roon", "Jan Schoonis", "Bjorn Schutz", "Joost Sneller", "Chris Stoffer", "Sebastiaan Stoteler", "Jan Struijs", "Luc Stultiens", "Henk Vermeer", "Marc Vervuurt", "Hans Vijlbrief", "Elmar Vlottes", "Geert Wilders"]
print(len(male_pols))
# Out:
# 85

# %%
malepol_toots = []

# Page 1
for name in male_pols:
    print("Searching for ", name)
    results = API.search_v2(name)
    statuses = results.get("statuses", [])

    for s in statuses:
        content = s.get("content", "")
        timestamp = s.get("created_at")
        if timestamp.year == 2025:
            malepol_toots.append({
                "text": content,
                "politician": name,
                "hate_speech": False,
                "hate_categories": []
            })


    print("First page returned", len(statuses), "statuses")

    # Next Page(s) if they exist
    # search_v2 returns something like results["statuses"][...]["id"]
    prev_last_id = None
    while len(statuses) > 0:
        print("Next page returned", len(statuses), "statuses")

        last_id = int(statuses[-1]["id"])
        if last_id == prev_last_id:
            print("Pagination stuck, breaking.")
            break
        prev_last_id = last_id

        results = API.search_v2(name, max_id=str(last_id - 1))
        statuses = results.get("statuses", [])

        if not statuses:
            break

        for s in statuses:
            content = s.get("content", "")
            timestamp = s.get("created_at")
            if timestamp.year == 2025:
                malepol_toots.append({
                    "text": content,
                    "politician": name,
                    "hate_speech": False,
                    "hate_categories": []
                })


        if timestamp.year < 2025:
            break
# Out:
# Searching for  Thierry Aartsen
# First page returned 20 statuses
# Next page returned 20 statuses
# Searching for  Ismail el Abassi
# First page returned 7 statuses
# Next page returned 7 statuses
# Searching for  Robert van Asten
# First page returned 0 statuses
# Searching for  Stephan van Baarle
# First page returned 19 statuses
# Next page returned 19 statuses
# Searching for  Mpanzu Bamenga
# First page returned 3 statuses
# Next page returned 3 statuses
# Searching for  Thierry Baudet
# First page returned 19 statuses
# Next page returned 19 statuses
# Next page returned 16 statuses
# Next page returned 20 statuses
# Next page returned 14 statuses
# Searching for  Daniel van den Berg
# First page returned 12 statuses
# Next page returned 12 statuses
# Searching for  Harry Bevers
# First page returned 1 statuses
# Next page returned 1 statuses
# Next page returned 1 statuses
# Pagination stuck, breaking.
# Searching for  Henri Botenbal
# First page returned 0 statuses
# Searching for  Diederik Boomsma
# First page returned 20 statuses
# Next page returned 20 statuses
# Searching for  Maikel Boon
# First page returned 13 statuses
# Next page returned 13 statuses
# Searching for  Martin Bosma
# First page returned 16 statuses
# Next page returned 16 statuses
# Next page returned 13 statuses
# Next page returned 19 statuses
# Next page returned 20 statuses
# Next page returned 20 statuses
# Searching for  Derk Boswijk
# First page returned 20 statuses
# Next page returned 20 statuses
# Searching for  Ruben Brekelmans
# First page returned 19 statuses
# Next page returned 19 statuses
# Next page returned 14 statuses
# Next page returned 16 statuses
# Next page returned 18 statuses
# Next page returned 17 statuses
# Next page returned 16 statuses
# Searching for  Tijs van den Brink
# First page returned 15 statuses
# Next page returned 15 statuses
# Next page returned 16 statuses
# Next page returned 20 statuses
# Searching for  Bart van den Brink
# First page returned 4 statuses
# Next page returned 4 statuses
# Searching for  Eric van der Burg
# First page returned 20 statuses
# Next page returned 20 statuses
# Next page returned 20 statuses
# Searching for  Julian Bushoff
# First page returned 19 statuses
# Next page returned 19 statuses
# Searching for  Thom van Campen
# First page returned 16 statuses
# Next page returned 16 statuses
# Next page returned 13 statuses
# Next page returned 18 statuses
# Searching for  Don Ceder
# First page returned 20 statuses
# Next page returned 20 statuses
# Searching for  Simon Ceulemans
# First page returned 2 statuses
# Next page returned 2 statuses
# Searching for  Rene Claassen
# First page returned 7 statuses
# Next page returned 7 statuses
# Searching for  Ranjith Clemminck
# First page returned 0 statuses
# Searching for  Laurens Dassen
# First page returned 18 statuses
# Next page returned 18 statuses
# Next page returned 20 statuses
# Searching for  Ralk Dekker
# First page returned 0 statuses
# Searching for  Tony van Dijck
# First page returned 4 statuses
# Next page returned 4 statuses
# Searching for  Jimmy Dijk
# First page returned 18 statuses
# Next page returned 18 statuses
# Next page returned 20 statuses
# Next page returned 20 statuses
# Next page returned 19 statuses
# Searching for  Emiel van Dijk
# First page returned 11 statuses
# Next page returned 11 statuses
# Searching for  Diederik van Dijk
# First page returned 20 statuses
# Next page returned 20 statuses
# Searching for  Peter van Duijvenvoorde
# First page returned 0 statuses
# Searching for  Joost Eerdmans
# First page returned 19 statuses
# Next page returned 19 statuses
# Next page returned 15 statuses
# Next page returned 16 statuses
# Next page returned 20 statuses
# Next page returned 20 statuses
# Next page returned 20 statuses
# Next page returned 20 statuses
# Searching for  Ulysse Ellian
# First page returned 13 statuses
# Next page returned 13 statuses
# Searching for  Dogukan Ergin
# First page returned 6 statuses
# Next page returned 6 statuses
# Searching for  Silvio Erkens
# First page returned 13 statuses
# Next page returned 13 statuses
# Searching for  Marjolein Faber
# First page returned 20 statuses
# Next page returned 20 statuses
# Next page returned 20 statuses
# Next page returned 20 statuses
# Next page returned 20 statuses
# Next page returned 20 statuses
# Next page returned 19 statuses
# Next page returned 19 statuses
# Next page returned 20 statuses
# Searching for  Andre Flach
# First page returned 18 statuses
# Next page returned 18 statuses
# Searching for  Maarten Goudzwaard
# First page returned 0 statuses
# Searching for  Dion Graus
# First page returned 20 statuses
# Next page returned 20 statuses
# Searching for  Pieter Grinwis
# First page returned 14 statuses
# Next page returned 14 statuses
# Searching for  Peter de Groot
# First page returned 19 statuses
# Next page returned 19 statuses
# Searching for  Sarath Hamstra
# First page returned 0 statuses
# Searching for  Eelco Heinen
# First page returned 20 statuses
# Next page returned 20 statuses
# Searching for  Hidde Heutink
# First page returned 4 statuses
# Next page returned 4 statuses
# Searching for  Michiel Hoogeveen
# First page returned 3 statuses
# Next page returned 3 statuses
# Searching for  Habtamu de Hoop
# First page returned 14 statuses
# Next page returned 14 statuses
# Searching for  Pepijn van Houwelingen
# First page returned 20 statuses
# Next page returned 20 statuses
# Searching for  Dion Huidekooper
# First page returned 1 statuses
# Next page returned 1 statuses
# Searching for  Frederik Jansen
# First page returned 6 statuses
# Next page returned 6 statuses
# Searching for  Chris Jansen
# First page returned 20 statuses
# Next page returned 20 statuses
# Searching for  Rob Jetten
# First page returned 14 statuses
# Next page returned 14 statuses
# Next page returned 13 statuses
# Next page returned 14 statuses
# Next page returned 15 statuses
# Next page returned 18 statuses
# Next page returned 17 statuses
# Next page returned 16 statuses
# Next page returned 17 statuses
# Next page returned 16 statuses
# Next page returned 15 statuses
# Next page returned 15 statuses
# Next page returned 16 statuses
# Next page returned 10 statuses
# Next page returned 12 statuses
# Next page returned 18 statuses
# Next page returned 15 statuses
# Next page returned 15 statuses
# Next page returned 11 statuses
# Next page returned 12 statuses
# Next page returned 14 statuses
# Next page returned 17 statuses
# Next page returned 20 statuses
# Next page returned 15 statuses
# Next page returned 14 statuses
# Next page returned 19 statuses
# Next page returned 15 statuses
# Next page returned 18 statuses
# Next page returned 18 statuses
# Next page returned 14 statuses
# Next page returned 13 statuses
# Next page returned 14 statuses
# Next page returned 20 statuses
# Next page returned 18 statuses
# Searching for  Henk Jumelet
# First page returned 3 statuses
# Next page returned 3 statuses
# Next page returned 1 statuses
# Pagination stuck, breaking.
# Searching for  Vincent Karremans
# First page returned 16 statuses
# Next page returned 16 statuses
# Next page returned 18 statuses
# Searching for  Arend Kisteman
# First page returned 2 statuses
# Next page returned 2 statuses
# Searching for  Jesse Klaver
# First page returned 15 statuses
# Next page returned 15 statuses
# Next page returned 14 statuses
# Next page returned 14 statuses
# Next page returned 15 statuses
# Next page returned 19 statuses
# Next page returned 20 statuses
# Next page returned 17 statuses
# Searching for  Felix Klos
# First page returned 7 statuses
# Next page returned 7 statuses
# Searching for  Jan Arie Koorevaar
# First page returned 0 statuses
# Searching for  Alexander Kops
# First page returned 16 statuses
# Next page returned 16 statuses
# Next page returned 19 statuses
# Searching for  Daan de Kort
# First page returned 15 statuses
# Next page returned 15 statuses
# Searching for  Ulas Kose
# First page returned 1 statuses
# Next page returned 1 statuses
# Searching for  Harmen Krul
# First page returned 6 statuses
# Next page returned 6 statuses
# Searching for  Maes van Lanschot
# First page returned 0 statuses
# Searching for  Tom van der Lee
# First page returned 19 statuses
# Next page returned 19 statuses
# Next page returned 20 statuses
# Searching for  Gidi Markuszower
# First page returned 20 statuses
# Next page returned 20 statuses
# Searching for  Gideon van Meijeren
# First page returned 20 statuses
# Next page returned 20 statuses
# Searching for  Mohammed Mohandis
# First page returned 4 statuses
# Next page returned 4 statuses
# Searching for  Jeremy Mooiman
# First page returned 5 statuses
# Next page returned 5 statuses
# Searching for  Edgar Mulder
# First page returned 7 statuses
# Next page returned 7 statuses
# Searching for  Stephen Neijenhuis
# First page returned 0 statuses
# Searching for  Jurgen Nobel
# First page returned 19 statuses
# Next page returned 19 statuses
# Searching for  Henk-Jan Oosterhuis
# First page returned 0 statuses
# Searching for  Jan Paternotte
# First page returned 18 statuses
# Next page returned 18 statuses
# Searching for  Erwin Prickaertz
# First page returned 0 statuses
# Searching for  Raymond de Roon
# First page returned 19 statuses
# Next page returned 19 statuses
# Searching for  Jan Schoonis
# First page returned 0 statuses
# Searching for  Bjorn Schutz
# First page returned 20 statuses
# Next page returned 20 statuses
# Searching for  Joost Sneller
# First page returned 20 statuses
# Next page returned 20 statuses
# Searching for  Chris Stoffer
# First page returned 18 statuses
# Next page returned 18 statuses
# Searching for  Sebastiaan Stoteler
# First page returned 4 statuses
# Next page returned 4 statuses
# Next page returned 1 statuses
# Pagination stuck, breaking.
# Searching for  Jan Struijs
# First page returned 8 statuses
# Next page returned 8 statuses
# Searching for  Luc Stultiens
# First page returned 8 statuses
# Next page returned 8 statuses
# Searching for  Henk Vermeer
# First page returned 20 statuses
# Next page returned 20 statuses
# Next page returned 20 statuses
# Next page returned 20 statuses
# Next page returned 20 statuses
# Next page returned 20 statuses
# Searching for  Marc Vervuurt
# First page returned 0 statuses
# Searching for  Hans Vijlbrief
# First page returned 20 statuses
# Next page returned 20 statuses
# Searching for  Elmar Vlottes
# First page returned 1 statuses
# Next page returned 1 statuses
# Next page returned 1 statuses
# Pagination stuck, breaking.
# Searching for  Geert Wilders
# First page returned 13 statuses
# Next page returned 13 statuses
# Next page returned 16 statuses
# Next page returned 17 statuses
# Next page returned 18 statuses
# Next page returned 19 statuses
# Next page returned 17 statuses
# Next page returned 18 statuses
# Next page returned 19 statuses
# Next page returned 17 statuses
# Next page returned 17 statuses
# Next page returned 16 statuses
# Next page returned 18 statuses
# Next page returned 17 statuses
# Next page returned 17 statuses
# Next page returned 17 statuses
# Next page returned 17 statuses
# Next page returned 19 statuses
# Next page returned 19 statuses
# Next page returned 17 statuses
# Next page returned 18 statuses
# Next page returned 20 statuses
# Next page returned 17 statuses
# Next page returned 17 statuses
# Next page returned 13 statuses
# Next page returned 15 statuses
# Next page returned 14 statuses
# Next page returned 12 statuses
# Next page returned 20 statuses
# Next page returned 20 statuses
# Next page returned 18 statuses
# Next page returned 18 statuses
# Next page returned 14 statuses
# Next page returned 18 statuses
# Next page returned 20 statuses
# Next page returned 20 statuses
# Next page returned 20 statuses
# Next page returned 20 statuses
# Next page returned 20 statuses
# Next page returned 19 statuses
# Next page returned 20 statuses
# Next page returned 20 statuses
# Next page returned 20 statuses
# Next page returned 19 statuses
# Next page returned 18 statuses
# Next page returned 20 statuses
# Next page returned 20 statuses
# Next page returned 19 statuses
# Next page returned 20 statuses
# Next page returned 20 statuses
# Next page returned 18 statuses
# Next page returned 20 statuses
# Next page returned 19 statuses
# Next page returned 20 statuses
# Next page returned 20 statuses
# Next page returned 18 statuses
# Next page returned 18 statuses
# Next page returned 15 statuses
# Next page returned 17 statuses
# Next page returned 19 statuses
# Next page returned 18 statuses
# Next page returned 20 statuses
# Next page returned 19 statuses
# Next page returned 18 statuses
# Next page returned 19 statuses
# Next page returned 20 statuses
# Next page returned 20 statuses
# Next page returned 17 statuses
# Next page returned 20 statuses
# Next page returned 19 statuses
# Next page returned 20 statuses
# Next page returned 20 statuses
# Next page returned 20 statuses
# Next page returned 15 statuses
# Next page returned 19 statuses
# Next page returned 19 statuses
# Next page returned 20 statuses
# Next page returned 20 statuses
# Next page returned 20 statuses
# Next page returned 20 statuses
# Next page returned 20 statuses
# Next page returned 20 statuses
# Next page returned 19 statuses
# Next page returned 20 statuses
# Next page returned 19 statuses
# Next page returned 19 statuses
# Next page returned 20 statuses
# Next page returned 20 statuses
# Next page returned 19 statuses
# Next page returned 19 statuses
# Next page returned 17 statuses
# Next page returned 20 statuses
# Next page returned 19 statuses

# %%
for post in malepol_toots:
    text_lower = post["text"].lower()
    post['hate_speech'] = False
    post['hate_categories'] = []
    
    for category, keywords in hate_keywords.items():
        for kw in keywords:
            kw_escaped = re.escape(kw)

            pattern = r'\b' + kw_escaped + r'\b'

            if re.search(pattern, text_lower):
                post['hate_speech'] = True
                post['hate_categories'].append(category)
                break


total = len(malepol_toots)
hate_count = len([p for p in malepol_toots if p['hate_speech']])

print(f"Total posts: {total}")
print(f"Posts with potential hate speech: {hate_count} ({hate_count/total*100:.1f}%)")
print(f"\nBreakdown by category:")

for category in hate_keywords.keys():
    count = len([p for p in malepol_toots if category in p.get('hate_categories', [])])
    print(f"  - {category}: {count}")
# Out:
# Total posts: 3939
# Posts with potential hate speech: 271 (6.9%)
#
# Breakdown by category:
#   - sexist: 9
#   - appearance: 70
#   - threats: 96
#   - misogyny: 3
#   - objectification: 30
#   - competence_undermining: 36
#   - dismissive: 24
#   - ethnic_religious_slurs: 27

# %% [markdown]
# Geert Wilders, as a very controversial figure, may be skewing the data significantly. Let's perform the same analysis for all the male politicians except Wilders.

# %%
minus_wilders = []
for post in malepol_toots:
    if post["politician"] != "Geert Wilders":
        minus_wilders.append(post)

for post in minus_wilders:import matplotlib.pyplot as plt
    text_lower = post["text"].lower()
    post['hate_speech'] = False
    post['hate_categories'] = []
    
    for category, keywords in hate_keywords.items():
        for kw in keywords:
            kw_escaped = re.escape(kw)

            pattern = r'\b' + kw_escaped + r'\b'

            if re.search(pattern, text_lower):
                post['hate_speech'] = True
                post['hate_categories'].append(category)
                break


total = len(minus_wilders)
hate_count = len([p for p in minus_wilders if p['hate_speech']])

print(f"Total posts: {total}")
print(f"Posts with potential hate speech: {hate_count} ({hate_count/total*100:.1f}%)")
print(f"\nBreakdown by category:")

for category in hate_keywords.keys():
    count = len([p for p in minus_wilders if category in p.get('hate_categories', [])])
    print(f"  - {category}: {count}")
# Out:
# Total posts: 2286
# Posts with potential hate speech: 162 (7.1%)
#
# Breakdown by category:
#   - sexist: 8
#   - appearance: 44
#   - threats: 54
#   - misogyny: 2
#   - objectification: 17
#   - competence_undermining: 25
#   - dismissive: 16
#   - ethnic_religious_slurs: 8

# %% [markdown]
# Set up pandas and get aggregate values.

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in ./lib/python3.12/site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.26.0 in ./lib/python3.12/site-packages (from pandas) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in ./lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in ./lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
#
# [notice] A new release of pip is available: 23.2.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd

# %%
dataframe = pd.DataFrame(name_toots)

agg = dataframe.groupby("politician").agg(
    total_toots = ("text", "count"),
    hate_toots  = ("hate_speech", "sum")
)

agg["non_hate_toots"] = agg["total_toots"] - agg["hate_toots"]

# %% [markdown]
# Create bar chart for female politician, displaying total toots against total toots containing hate speech.

# %%
# !pip install matplotlib
# Out:
# Collecting matplotlib
#   Obtaining dependency information for matplotlib from https://files.pythonhosted.org/packages/be/b3/09eb0f7796932826ec20c25b517d568627754f6c6462fca19e12c02f2e12/matplotlib-3.10.7-cp312-cp312-macosx_10_13_x86_64.whl.metadata
#   Using cached matplotlib-3.10.7-cp312-cp312-macosx_10_13_x86_64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Obtaining dependency information for contourpy>=1.0.1 from https://files.pythonhosted.org/packages/be/45/adfee365d9ea3d853550b2e735f9d66366701c65db7855cd07621732ccfc/contourpy-1.3.3-cp312-cp312-macosx_10_13_x86_64.whl.metadata
#   Using cached contourpy-1.3.3-cp312-cp312-macosx_10_13_x86_64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Obtaining dependency information for cycler>=0.10 from https://files.pythonhosted.org/packages/e7/05/c19819d5e3d95294a6f5947fb9b9629efb316b96de511b418c53d245aae6/cycler-0.12.1-py3-none-any.whl.metadata
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Obtaining dependency information for fonttools>=4.22.0 from https://files.pythonhosted.org/packages/25/b2/0658faf66f705293bd7e739a4f038302d188d424926be9c59bdad945664b/fonttools-4.61.0-cp312-cp312-macosx_10_13_x86_64.whl.metadata
#   Downloading fonttools-4.61.0-cp312-cp312-macosx_10_13_x86_64.whl.metadata (113 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.2/113.2 kB 872.8 kB/s eta 0:00:0000:0100:01
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Obtaining dependency information for kiwisolver>=1.3.1 from https://files.pythonhosted.org/packages/51/ea/2ecf727927f103ffd1739271ca19c424d0e65ea473fbaeea1c014aea93f6/kiwisolver-1.4.9-cp312-cp312-macosx_10_13_x86_64.whl.metadata
#   Using cached kiwisolver-1.4.9-cp312-cp312-macosx_10_13_x86_64.whl.metadata (6.3 kB)
# Requirement already satisfied: numpy>=1.23 in ./lib/python3.12/site-packages (from matplotlib) (2.3.5)
# Requirement already satisfied: packaging>=20.0 in ./lib/python3.12/site-packages (from matplotlib) (25.0)
# Collecting pillow>=8 (from matplotlib)
#   Obtaining dependency information for pillow>=8 from https://files.pythonhosted.org/packages/2c/90/4fcce2c22caf044e660a198d740e7fbc14395619e3cb1abad12192c0826c/pillow-12.0.0-cp312-cp312-macosx_10_13_x86_64.whl.metadata
#   Using cached pillow-12.0.0-cp312-cp312-macosx_10_13_x86_64.whl.metadata (8.8 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Obtaining dependency information for pyparsing>=3 from https://files.pythonhosted.org/packages/10/5e/1aa9a93198c6b64513c9d7752de7422c06402de6600a8767da1524f9570b/pyparsing-3.2.5-py3-none-any.whl.metadata
#   Using cached pyparsing-3.2.5-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in ./lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in ./lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Using cached matplotlib-3.10.7-cp312-cp312-macosx_10_13_x86_64.whl (8.3 MB)
# Using cached contourpy-1.3.3-cp312-cp312-macosx_10_13_x86_64.whl (293 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.61.0-cp312-cp312-macosx_10_13_x86_64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 3.1 MB/s eta 0:00:0000:0100:01
# Using cached kiwisolver-1.4.9-cp312-cp312-macosx_10_13_x86_64.whl (66 kB)
# Using cached pillow-12.0.0-cp312-cp312-macosx_10_13_x86_64.whl (5.2 MB)
# Using cached pyparsing-3.2.5-py3-none-any.whl (113 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.61.0 kiwisolver-1.4.9 matplotlib-3.10.7 pillow-12.0.0 pyparsing-3.2.5
#
# [notice] A new release of pip is available: 23.2.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
import matplotlib.pyplot as plt

# %%
ax = agg[["non_hate_toots", "hate_toots"]].plot(
    kind="bar",
    stacked=True,
    figsize=(12, 6)
)

ax.legend(["Not Containing Hate Speech", "Containing Hate Speech"])

# Percentage labels above each bar
for i, (non_hate, hate) in enumerate(zip(agg['non_hate_toots'], agg['hate_toots'])):
    total = non_hate + hate
    if total > 0:
        pct = hate / total * 100
        if pct > 0.0:
            ax.text(
                i,
                total + 2,
                f"{pct:.1f}%",
                ha='center', va='bottom', fontsize=8, rotation=0
            )

ax.set_xlabel("Politician")
ax.set_ylabel("Number of toots")
ax.set_title("Total Toots per Female Politician (with Hate Speech Subset)")
plt.xticks(rotation=45, ha="right")

plt.tight_layout()
plt.show()

# %% [markdown]
# Next, do the same for male politicians.

# %%
dataframe = pd.DataFrame(malepol_toots)

agg = dataframe.groupby("politician").agg(
    total_toots = ("text", "count"),
    hate_toots  = ("hate_speech", "sum")
)

agg["non_hate_toots"] = agg["total_toots"] - agg["hate_toots"]

## This line removes all politicians from the graph that did not have any toots gathered about them. 
## Doing so means that the graph does not have EVERY male politician in it, but also makes it less cluttered by removing irrelevant names.
## Comment out the line below to have every male politician reflected.
agg = agg[(agg["total_toots"] > 0) & (~agg["total_toots"].isna())]

ax = agg[["non_hate_toots", "hate_toots"]].plot(
    kind="bar",
    stacked=True,
    figsize=(12, 6)
)

ax.legend(["Not Containing Hate Speech", "Containing Hate Speech"])

# Percentage labels above each bar
for i, (non_hate, hate) in enumerate(zip(agg['non_hate_toots'], agg['hate_toots'])):
    total = non_hate + hate
    if total > 0:
        pct = hate / total * 100
        if pct > 0.0:
            ax.text(
                i,
                total + 2,
                f"{pct:.1f}%",
                ha='center', va='bottom', fontsize=8, rotation=0
            )

ax.set_xlabel("Politician")
ax.set_ylabel("Number of toots")
ax.set_title("Total Toots per Male Politician (with Hate Speech Subset)")
plt.xticks(rotation=45, ha="right")

plt.tight_layout()
plt.show()

# %% [markdown]
# We can see here that even though we had assumed Geert Wilders might be an outlier, he does not have an above normal percentage of hate speech in his mentions, and many male politicians even have more hate speech in their content.

# %% [markdown]
# Next, we can visualize the percentages of toots with each kind of hate speech for female politicians using pie charts.

# %%
category_counts = {
    category: len([p for p in name_toots if category in p.get('hate_categories', [])])
    for category in hate_keywords.keys()
}

total_posts = len(name_toots)

colors = ["#1f77b4", "#ff7f0e"]   # [non-hate, hate]

pretty_labels = {
    "sexist": "Sexism",
    "appearance": "Appearance-Related",
    "threats": "Threats",
    "misogyny": "Misogyny",
    "objectification": "Objectification",
    "competence_undermining": "Competence-Undermining",
    "dismissive": "Dismissive",
    "ethnic_religious_slurs": "Ethnic or Religious Slurs"
}

fig, axes = plt.subplots(2, 4, figsize=(18, 9))
axes = axes.flatten()

for i, (category, count) in enumerate(category_counts.items()):
    ax = axes[i]

    hate_pct = (count / total_posts) * 100 if total_posts > 0 else 0
    sizes = [total_posts - count, count]

    ax.pie(
        sizes,
        colors=colors,
        autopct=lambda pct: f"{pct:.1f}%" if pct > 0 else "",
        startangle=90,
        textprops={'fontsize': 8}
    )

    ax.set_title(f"{pretty_labels[category]}\n({hate_pct:.1f}% of all toots)", fontsize=10)

plt.tight_layout()
plt.show()

# %% [markdown]
# And we can do the same for male politicians.

# %%
category_counts = {
    category: len([p for p in malepol_toots if category in p.get('hate_categories', [])])
    for category in hate_keywords.keys()
}

total_posts = len(name_toots)

colors = ["#1f77b4", "#ff7f0e"]   # [non-hate, hate]

pretty_labels = {
    "sexist": "Sexism",
    "appearance": "Appearance-Related",
    "threats": "Threats",
    "misogyny": "Misogyny",
    "objectification": "Objectification",
    "competence_undermining": "Competence-Undermining",
    "dismissive": "Dismissive",
    "ethnic_religious_slurs": "Ethnic or Religious Slurs"
}

fig, axes = plt.subplots(2, 4, figsize=(18, 9))
axes = axes.flatten()

for i, (category, count) in enumerate(category_counts.items()):
    ax = axes[i]

    hate_pct = (count / total_posts) * 100 if total_posts > 0 else 0
    sizes = [total_posts - count, count]

    ax.pie(
        sizes,
        colors=colors,
        autopct=lambda pct: f"{pct:.1f}%" if pct > 0 else "",
        startangle=90,
        textprops={'fontsize': 8}
    )

    ax.set_title(f"{pretty_labels[category]}\n({hate_pct:.1f}% of all toots)", fontsize=10)

plt.tight_layout()
plt.show()
