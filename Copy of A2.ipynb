# %% [markdown]
# *****************************************************************
# #  The Social Web: data representation
# - Instructors: Davide Ceolin, Emma Beauxis-Aussalet.
# - TAs: Zubaria Inayat, Maxim Sergeev, Zhuofan Mei, Alexander Schmatz, Ling Jin.
# - Exercises for Hands-on session 2
# *****************************************************************

# %% [markdown]
# In this session you are going to mine data in various microformats. You will see the differences in what each of the formats can contain and what purpose they serve. We will start by looking at geographical data.
#
# Prerequisites:
# - Python 3.8
# - Python packages: requests, BeautifulSoup4, HTMLParser, rdflib

# %%
# If you're using a virtualenv, make sure it's activated before running
# this cell!
# !pip install requests
# !pip install BeautifulSoup4
# !pip install HTMLParser
# !pip install rdflib
# !pip install cloudscraper
# Out:
# Requirement already satisfied: requests in ./lib/python3.12/site-packages (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./lib/python3.12/site-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in ./lib/python3.12/site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./lib/python3.12/site-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./lib/python3.12/site-packages (from requests) (2025.10.5)
#
# [notice] A new release of pip is available: 23.2.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: BeautifulSoup4 in ./lib/python3.12/site-packages (4.14.2)
# Requirement already satisfied: soupsieve>1.2 in ./lib/python3.12/site-packages (from BeautifulSoup4) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in ./lib/python3.12/site-packages (from BeautifulSoup4) (4.15.0)
#
# [notice] A new release of pip is available: 23.2.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: HTMLParser in ./lib/python3.12/site-packages (0.0.2)
#
# [notice] A new release of pip is available: 23.2.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: rdflib in ./lib/python3.12/site-packages (7.4.0)
# Requirement already satisfied: pyparsing<4,>=2.1.0 in ./lib/python3.12/site-packages (from rdflib) (3.2.5)
#
# [notice] A new release of pip is available: 23.2.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: cloudscraper in ./lib/python3.12/site-packages (1.2.71)
# Requirement already satisfied: pyparsing>=2.4.7 in ./lib/python3.12/site-packages (from cloudscraper) (3.2.5)
# Requirement already satisfied: requests>=2.9.2 in ./lib/python3.12/site-packages (from cloudscraper) (2.32.5)
# Requirement already satisfied: requests-toolbelt>=0.9.1 in ./lib/python3.12/site-packages (from cloudscraper) (1.0.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./lib/python3.12/site-packages (from requests>=2.9.2->cloudscraper) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in ./lib/python3.12/site-packages (from requests>=2.9.2->cloudscraper) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./lib/python3.12/site-packages (from requests>=2.9.2->cloudscraper) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./lib/python3.12/site-packages (from requests>=2.9.2->cloudscraper) (2025.10.5)
#
# [notice] A new release of pip is available: 23.2.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ##  Exercise 1
#
# Even if web pages do not use microformat, interesting data can often be extracted from the HTML. You may use packages such as BeautifulSoup to extract arbitrary pieces of data from any HTML page.
# The example below shows how we can find the URL of first image in the infobox table of the wikipedia page on Amsterdam. Tip: compare the code below with HTML source code of the wikipedia page: the image url is in the "src" attribute of the "img" element of in the "table" element with class="infobox".

# %%
# -*- coding: utf-8 -*-

import requests
from bs4 import BeautifulSoup

# This script requires you to add a url of a page with geotags to the commandline, e.g.
# python geo.py 'http://en.wikipedia.org/wiki/Amsterdam'
URL = 'https://en.wikipedia.org/wiki/Amsterdam'

req = requests.get(URL, headers={'User-Agent' : "Social Web Course Student"})
soup = BeautifulSoup(req.text)
# print(req.text)
image1 = soup.findAll('table', class_='infobox')[0].find('img')
print(image1['src'])
# Out:
# //upload.wikimedia.org/wikipedia/commons/thumb/5/57/Imagen_de_los_canales_conc%C3%A9ntricos_en_%C3%81msterdam.png/330px-Imagen_de_los_canales_conc%C3%A9ntricos_en_%C3%81msterdam.png
# /var/folders/7h/j5323bpj7vdg5v2ch2lzwyqh0000gn/T/ipykernel_37800/3238900345.py:13: DeprecationWarning: Call to deprecated method findAll. (Replaced by find_all) -- Deprecated since version 4.0.0.
#   image1 = soup.findAll('table', class_='infobox')[0].find('img')

# %% [markdown]
# Extracting coordinates from a webpage and reformatting them in the geo microformat (based on Example 8-1 in Mining the Social Web). Note that wikipages may encode long/lat information in different ways. On of the ways used by the Amsterdam wikipedia page is in a span element that is not shown to the user:
# <span class="geo">52.367; 4.900</span>
# This span element has a single child: len(geoTag == 1) and no further structure, we have to manually get the long/lat by splitting the string on the ';' semicolon.

# %%
geoTag = soup.find(True, 'geo')
print(geoTag)

if geoTag and len(geoTag) > 1:
        lat = geoTag.find(True, 'latitude').string
        lon = geoTag.find(True, 'longitude').string
        print ('Location is at'), lat, lon
elif geoTag and len(geoTag) == 1:
        (lat, lon) = geoTag.string.split(';')
        (lat, lon) = (lat.strip(), lon.strip())
        print (('Location is at'), lat, lon)
else:
        print ('Location not found')
# Out:
# <span class="geo">52.37278; 4.89361</span>
# Location is at 52.37278 4.89361

# %% [markdown]
# ### Task 1
#
# Can you convert the output of Exercise 1 into KML? Here is the KML documentation: https://developers.google.com/kml/documentation/?csw=1 and here you can find a simple example of how it is used: https://renenyffenegger.ch/notes/tools/Google-Earth/kml/index
#
# Visualise the point in Google Maps using the following code example: https://developers.google.com/maps/documentation/javascript/examples/layer-kml-features
# You will have to create your own KML file for the custom map layer, and provide a URL to the KML file inside the JavaScript code, which means that you have to upload the file somewhere. You can use a service like http://pastebin.com/ to obtain a URL for your KML file —> paste the code there and request the RAW format URL; use this one in this Task1. If it fails to work you can also use KML viewer websites like https://kmzview.com/.
#
# Is KML a microformat, why (not)?

# %%
# This code is from my KML file, which I uploaded to kmzview.com and worked successfully.

"""
<?xml version="1.0" encoding="UTF-8"?>
<kml xmlns="http://www.opengis.net/kml/2.2">
  <Placemark>
    <name>A2: T1</name>
    <description>Task 1</description>
    <Point>
      <coordinates>52.37278,4.89361,0</coordinates>
    </Point>
  </Placemark>
</kml>
"""
# Out:
# '\n<?xml version="1.0" encoding="UTF-8"?>\n<kml xmlns="http://www.opengis.net/kml/2.2">\n  <Placemark>\n    <name>A2: T1</name>\n    <description>Task 1</description>\n    <Point>\n      <coordinates>52.37278,4.89361,0</coordinates>\n    </Point>\n  </Placemark>\n</kml>\n'

# %% [markdown]
# No, KML is not a microformat. Microformats need to be HTML elements, where KML is an element of XML.

# %% [markdown]
# ## Exercise 2
# In order to find information in the web we can use microformats such as [hRecipe](https://microformats.org/wiki/hrecipe) or Schema.org's [Recipe](https://schema.org/Recipe). But first, we'll show you how to find arbitrary tags in a webpage.

# %% [markdown]
# ### Task 2
# Parsing data for a <sub><sup>veggie</sup></sub> spaghetti alla carbonara recipe (from Example 2-7 in Mining the Social Web).

# %%
import cloudscraper
import json
from bs4 import BeautifulSoup

# A yummy webpage (feel free to change to your likings.)
URL = "https://www.acouplecooks.com/spring-vegetarian-spaghetti-carbonara"

# Create a CloudScraper object
scraper = cloudscraper.create_scraper()

# Use the CloudScraper object to fetch the HTML content
response = scraper.get(URL)

# Parse the HTML content with BeautifulSoup
soup = BeautifulSoup(response.text, 'html.parser')

# Now you can work with the 'soup' object as you did before
listchildren = list(soup.children)
#print(listchildren)

# %% [markdown]
# We can find any element in the page through *css tag selectors*
# You can find them all [here](https://www.w3schools.com/cssref/css_selectors.asp), but shortly these are "." for classes, # for ids and plain text for the element name.
#
#
# You can also combine them, so that looking for ".class1.class2" would select all elements displaying both classes. For a deeper overview please check the above link (or google "html tag selectors").

# %%
print(len(listchildren)) # we can see here how many children the html doc has got.
title_unparsed = soup.select_one("title")
#show the title element
print(title_unparsed)
# Out:
# 2
# <title>Vegetarian Carbonara – A Couple Cooks</title>

# %% [markdown]
# Not so pretty.... Use the text method.

# %%
print(title_unparsed.text)
# Out:
# Vegetarian Carbonara – A Couple Cooks

# %% [markdown]
# The website has a block of JSON-LD data embedded. Try to see if you can find it in the soup object.
# We can load the JSON-LD script to work with it easier.
# Lets get a list of the ingredients.

# %%
# Find the script tag containing the JSON-LD data
json_ld_script = soup.find("script", {"class": "yoast-schema-graph"})

# Extract the content of the script tag
script_content = json_ld_script.string

# Load the JSON data from the script content
data = json.loads(script_content)

# Access the "recipeIngredient" list
recipe_ingredients = data["@graph"][7]["recipeIngredient"]

# Print the list of ingredients
for ingredient in recipe_ingredients:
    print(ingredient)
# Out:
# 1 pound spaghetti noodles
# ½ cup smoked mozzarella cheese
# ½ cup grated Parmesan cheese, plus more for serving
# 4 egg yolks
# 1 cup frozen Earthbound Farm Organic peas
# 8 cups Earthbound Farm Organic spinach
# 3 tablespoons butter
# Kosher salt
# Fresh ground black pepper

# %% [markdown]
# Lets also print out the instructions.

# %%
recipe_instructions= data["@graph"][7]["recipeInstructions"]
#the instructions list contains dictionaries as elements, take a look at how the list is organized
for step in recipe_instructions:
    print(step["text"])
# Out:
# In a large pot, combine 6 quarts of water with 2 tablespoons kosher salt and bring it to a boil.
# Grate the Parmesan and mozzarella cheese. Carefully separate four egg yolks and set aside.
# Once boiling, add the pasta and cook until the pasta is just about al dente, about 7 minutes; then add peas and spinach and cook for 1 minute. Reserve 1 cup cooking water, and then drain the pasta and vegetables.
# In a skillet, melt the butter, then stir in the cheeses, ¼ cup pasta water, and ¼ teaspoon kosher salt. Stir in the pasta and vegetables until creamy over low heat, adding more pasta water if necessary (note that the mozzarella will stick together in some places).
# To serve, top each pasta serving with a whole egg yolk and additional Parmesan cheese, and stir the yolk into the pasta at the table (if you are uncomfortable serving egg yolks at the table, stir the egg yolks into the pasta in the skillet to heat them through). Serve immediately. (Note that the mozzarella cheese can become gummy the longer the pasta sits, so eat immediately if possible. Leftovers can be reheated in a skillet, but may not have the same creamy texture.)

# %% [markdown]
# Websites are going to be structured differently. Look at the following JSON-DL snippet.

# %%
json_example = {
    "title": "The anarchist cookbook",
    "recipeInstructions": "<ol class=\"recipeSteps\"><li>Cook the linguine according to the packet instructions. </li><li>Meanwhile, carefully crack the eggs into a small bowl and beat them with a fork. Season with a little black pepper, then stir in the ricotta finely grate in most of the lemon zest. </li><li>When the pasta has 3 minutes left, add the peas. Reserve a little cooking water, then drain the linguine and peas, and return to the pan. </li><li>Stir in the egg mixture and spinach with a wooden spoon – they'll cook gently in the residual heat. Add a little pasta water to loosen, if needed. </li><li>Share between bowls and serve with a green salad.</li></ol>",
    "ingredients": ["a lot of effort", "the right mindset"]
}

recipe_instructions = json_example["recipeInstructions"]
example_soup = BeautifulSoup(recipe_instructions, 'html.parser')

# %%
#to get a nice and clean list of the instructions, step by step
#we can use the find method to get the first "ol" element with attribute "class.." and then use find_all to get all list elements in there
#then we can strip the list items to obtain the instructions
list_items = example_soup.find('ol', class_='recipeSteps').find_all('li')
instructions = [item.get_text(strip=True) for item in list_items]
print(instructions)
# Out:
# ['Cook the linguine according to the packet instructions.', 'Meanwhile, carefully crack the eggs into a small bowl and beat them with a fork. Season with a little black pepper, then stir in the ricotta finely grate in most of the lemon zest.', 'When the pasta has 3 minutes left, add the peas. Reserve a little cooking water, then drain the linguine and peas, and return to the pan.', "Stir in the egg mixture and spinach with a wooden spoon – they'll cook gently in the residual heat. Add a little pasta water to loosen, if needed.", 'Share between bowls and serve with a green salad.']

# %% [markdown]
# ## Task 2.1
# Now it's your turn. Create a function that can scrape any recipe webpage from the same website (other websites will have different class tags).
#
# Make sure to:
#
# - return itemized content (e.g. ingredients) in a list. You may want to use a list comprehension here.
# - Not all items have been cleaned of their html markdown (see variables ```ingredients``` vs. ```instructions_unparsed```. Make sure to return a list with human readable content (i.e. by using the ```.text``` attribute).

# %%
#Here you can see the solution for our example website

URL = "https://www.acouplecooks.com/spring-vegetarian-spaghetti-carbonara"

def parse_website(url):
    # Create a CloudScraper object
    scraper = cloudscraper.create_scraper()

    # Use the CloudScraper object to fetch the HTML content
    response = scraper.get(URL)

    # Parse the HTML content with BeautifulSoup
    soup = BeautifulSoup(response.text, 'html.parser')
    
    #Get the title
    title_unparsed = soup.select_one("title")
    fn = title_unparsed.text
    
    json_ld_script = soup.find("script", {"class": "yoast-schema-graph"})

    # Extract the content of the script tag
    script_content = json_ld_script.string

    # Load the JSON data from the script content
    data = json.loads(script_content)

    # Access the "recipeIngredient" list
    recipe_ingredients = data["@graph"][7]["recipeIngredient"]
    
    ingredients = [ingredient for ingredient in recipe_ingredients]
    
    #Access the instructions
    recipe_instructions= data["@graph"][7]["recipeInstructions"]
    #the instructions list contains dictionaries as elements, take a look at how the list is organized
    instructions = [step["text"] for step in recipe_instructions]

    return {'name': fn,
            'ingredients': ingredients,
            'instructions': instructions,
            }
    
recipe = parse_website(URL)
print (recipe)
# Out:
# {'name': 'Vegetarian Carbonara – A Couple Cooks', 'ingredients': ['1 pound spaghetti noodles', '½ cup smoked mozzarella cheese', '½ cup grated Parmesan cheese, plus more for serving', '4 egg yolks', '1 cup frozen Earthbound Farm Organic peas', '8 cups Earthbound Farm Organic spinach', '3 tablespoons butter', 'Kosher salt', 'Fresh ground black pepper'], 'instructions': ['In a large pot, combine 6 quarts of water with 2 tablespoons kosher salt and bring it to a boil.', 'Grate the Parmesan and mozzarella cheese. Carefully separate four egg yolks and set aside.', 'Once boiling, add the pasta and cook until the pasta is just about al dente, about 7 minutes; then add peas and spinach and cook for 1 minute. Reserve 1 cup cooking water, and then drain the pasta and vegetables.', 'In a skillet, melt the butter, then stir in the cheeses, ¼ cup pasta water, and ¼ teaspoon kosher salt. Stir in the pasta and vegetables until creamy over low heat, adding more pasta water if necessary (note that the mozzarella will stick together in some places).', 'To serve, top each pasta serving with a whole egg yolk and additional Parmesan cheese, and stir the yolk into the pasta at the table (if you are uncomfortable serving egg yolks at the table, stir the egg yolks into the pasta in the skillet to heat them through). Serve immediately. (Note that the mozzarella cheese can become gummy the longer the pasta sits, so eat immediately if possible. Leftovers can be reheated in a skillet, but may not have the same creamy texture.)']}

# %%
# -*- coding: utf-8 -*-

import cloudscraper
import json
from bs4 import BeautifulSoup

URL = "https://www.acouplecooks.com/rhubarb-pie/"

def parse_website(url):
    # Create a CloudScraper object
    scraper = cloudscraper.create_scraper()
    # Use the CloudScraper object to fetch the HTML content
    response = scraper.get(URL)
    # Parse the HTML content with BeautifulSoup
    soup = BeautifulSoup(response.text, 'html.parser')
    #Get the title
    title_unparsed = soup.select_one("title")
    fn = title_unparsed.text
    json_ld_script = soup.find("script", {"class": "yoast-schema-graph"})
    # Extract the content of the script tag
    script_content = json_ld_script.string
    # Load the JSON data from the script content
    data = json.loads(script_content)
    # Access the "recipeIngredient" list
    recipe_ingredients = data["@graph"][7]["recipeIngredient"]
    ingredients = [ingredient for ingredient in recipe_ingredients]
    #Access the instructions
    recipe_instructions= data["@graph"][7]["recipeInstructions"]
    #the instructions list contains dictionaries as elements, take a look at how the list is organized
    instructions = [step["text"] for step in recipe_instructions]
    return {'name': fn,
            'ingredients': ingredients,
            'instructions': instructions,
            }

recipe = parse_website(URL)
print (recipe)
# Out:
# {'name': 'Classic Rhubarb Pie – A Couple Cooks', 'ingredients': ['1 Homemade Pie Crust (or your favorite recipe)', '6 cups diced rhubarb (about 2 pounds)', '1 1/4 cups granulated sugar', '1/4 cup cornstarch', '2 teaspoons vanilla extract', '1/4 teaspoon orange zest (or 1/2 teaspoon lemon zest)', '1/2 cup all-purpose flour', '1/4 cup light brown sugar, packed', '1/4 teaspoon cinnamon', '1 pinch kosher salt', '4 tablespoons salted butter, melted'], 'instructions': ['In a large skillet, mix the chopped rhubarb with sugar and place it on the counter. Allow it to sit and macerate at room temperature for 30 minutes while making the pie crust (this extracts the juices of the rhubarb; do not skip this step!).\xa0', 'Make the pie crust. Refrigerate while you make the topping.', 'Preheat the oven to 400°F.\xa0', 'Place the skillet on a burner on the stove. Stir in the cornstarch, orange zest, and vanilla extract. Add medium high heat and cook about 5 to 6 minutes, until the sauce becomes very thick (but not longer, since the rhubarb will cook in the oven).\xa0', 'Make the crumble topping: In a medium bowl, add the flour, brown sugar, cinnamon, and kosher salt. Mix together with a fork. Pour in the melted butter while mixing with the fork until a crumbly mixture forms.\xa0', 'Roll out the pie dough, transfer it to a standard 9-inch pie pan, and crimp the edges (following these instructions). Pour in the rhubarb filling. Use your fingers to sprinkle the crumbles evenly over the filling.', 'Place the pie on a large baking sheet and bake for 15 minutes.', 'Keep the pie in the oven and turn the oven temperature down to 350°F. Bake for 30 to 40 minutes until the crust and crumble topping are golden. (Check on the pie around 20 minutes and cover with aluminum foil if the crust is getting too brown.)', 'Remove from the oven. Allow the pie to cool for 3 hours at room temperature before serving.']}

# %% [markdown]
# But How can we get information not only from one website,  but from all?
#
# The answer: microformats.
#
# But rather than extracting with information manually from the schema.org or hRecipe microformats, we can use a package, ```scrape-schema-recipe```
#
# Feel free to experiment with it.

# %% [markdown]
# ### Task 2.2
# hRecipe is a microformat specifically created for recipes.
# Can you for example easily compare different dessert recipe ingredients? For inspiration you can look back at the exercises you did in Hands-on session 1 where you compared different sets of tweets.

# %%
import scrape_schema_recipe

# Recipe 1

URL = "https://www.allrecipes.com/recipe/12316/fresh-rhubarb-pie/"

recipe_list = scrape_schema_recipe.scrape_url(URL, python_objects=True)
recipe = recipe_list[0]

ingredients1 = recipe['recipeIngredient']

# Recipe 2 (This is copy and pasted from above)

URL2 = "https://www.acouplecooks.com/rhubarb-pie/"

scraper2 = cloudscraper.create_scraper()
response2 = scraper2.get(URL2)
soup2 = BeautifulSoup(response2.text, 'html.parser')
json_ld_script = soup2.find("script", {"class": "yoast-schema-graph"})
script_content = json_ld_script.string
data = json.loads(script_content)
recipe_ingredients = data["@graph"][7]["recipeIngredient"]

ingredients2 = [ingredient for ingredient in recipe_ingredients]

for ingredient in ingredients1:
    if ingredient not in ingredients2:
        print(ingredient)

print()

for ingredient in ingredients2:
    if ingredient not in ingredients1:
        print(ingredient)

# It makes sense that all ingredients are printed, since there are no identical amounts of ingredients.
# Out:
# 1.3333333730698 cups white sugar
# 6 tablespoons all-purpose flour
# 1 (14.1 ounce) package double-crust pie pastry, thawed
# 4 cups chopped rhubarb
# 1 tablespoon butter
#
# 1 Homemade Pie Crust (or your favorite recipe)
# 6 cups diced rhubarb (about 2 pounds)
# 1 1/4 cups granulated sugar
# 1/4 cup cornstarch
# 2 teaspoons vanilla extract
# 1/4 teaspoon orange zest (or 1/2 teaspoon lemon zest)
# 1/2 cup all-purpose flour
# 1/4 cup light brown sugar, packed
# 1/4 teaspoon cinnamon
# 1 pinch kosher salt
# 4 tablespoons salted butter, melted

# %% [markdown]
# ## Exercise 3

# %% [markdown]
# Schema.org is one of the most widely used annotations formats. Schema.org is a multipurpose  template that has been created by a consortium consisting of Yahoo!, Google and Microsoft. It can describe entities, events, products etc. Check out the vocabulary specs on Schema.org.

# %% [markdown]
# ### Task 3
#
# Parsing schema.org microdata. To parse this data you need to install the rdflib-microdata package, which you have done in one of the previous steps.

# %%
from rdflib import Graph

# Source: https://www.youtube.com/watch?v=sCU214rbRZ0
# Pass in a URL containing Schema.org microformats
URL = "http://dbpedia.org/resource/Micheal_Jackson"

# Initialize a graph
g = Graph()

# Parse in an RDF file graph dbpedia
result = g.parse(location=URL)

# Loop through first 10 triples in the graph
for index, (sub, pred, obj) in enumerate(g):
    print(sub, pred, obj)
    if index == 10:
        break
# Out:
# http://dbpedia.org/resource/Micheal_Jackson http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Michael_Jackson
# http://dbpedia.org/resource/Micheal_Jackson http://dbpedia.org/ontology/wikiPageRedirects http://dbpedia.org/resource/Michael_Jackson

# %%
# Print the size of the Graph
print(f'Graph has {len(g)} facts')
# Out:
# Graph has 2 facts

# %%
# Print out the entire Graph in the RDF Turtle format
print(g.serialize(format='ttl'))
# Out:
# @prefix ns1: <http://dbpedia.org/ontology/> .
#
# <http://dbpedia.org/resource/Micheal_Jackson> ns1:wikiPageRedirects <http://dbpedia.org/resource/Michael_Jackson> ;
#     ns1:wikiPageWikiLink <http://dbpedia.org/resource/Michael_Jackson> .

# %% [markdown]
# ### Task 3.1
# Compare the schema.org information about a band on last.fm to the Facebook Open Graph information about the same band from Facebook. What are the differences? Which format do you think supports better interoperability? In particular, refer to the Microformat specifications indicated in the box on the top right corner.

# %%
import requests, json, extruct

url_lastfm = "https://www.last.fm/music/The+Beatles"
headers = {"User-Agent": "Mozilla/5.0"}
html_lastfm = requests.get(url_lastfm, headers=headers).text

data_lastfm = extruct.extract(
    html_lastfm,
    base_url=url_lastfm,
    syntaxes=['json-ld', 'microdata', 'opengraph']
)

print(json.dumps(data_lastfm['json-ld'], indent=2))


print("-------------------------------------------------------")

# Facebook Open Graph
fb_url = "https://www.facebook.com/thebeatles"
html_fb = requests.get(fb_url, headers={'User-Agent': 'Mozilla/5.0'}).text
soup_fb = BeautifulSoup(html_fb, "html.parser")

og_tags = soup_fb.find_all("meta", property=lambda p: p and p.startswith("og:"))

og_data = {tag.get("property"): tag.get("content") for tag in og_tags if tag.get("content")}

print(json.dumps(og_data, indent=2))

# From online research, it seems that last.fm has removed semantic markup (rdf). Thus, in some ways, it seems that Facebook's Open Graph
# would be more interoperable simply from an accessibility standpoint. However, I did research what last.fm data would have looked like, if
# I had been able to access it. Where Facebook's data all begins with "og:", making it FB-specific, last.fm is much more generic, with 
# intuitive titles that seem like they could be used across platforms (like name, genre, url). In this sense, last.fm would be much 
# more interoperable.
# Out:
# []
# -------------------------------------------------------
# {
#   "og:type": "video.other",
#   "og:title": "The Beatles",
#   "og:description": "The Beatles. 39.252.540 vind-ik-leuks \u00b7 65.337 personen praten hierover. New casting announced for The Beatles - A Four-Film Cinematic Event, directed by Sam Mendes....",
#   "og:url": "https://www.facebook.com/thebeatles",
#   "og:image:alt": "The Beatles",
#   "og:image": "https://scontent-ams2-1.xx.fbcdn.net/v/t1.6435-1/57964042_10157220713559539_1721715379509657600_n.jpg?stp=dst-jpg_tt6&cstp=mx1134x1134&ctp=s720x720&_nc_cat=1&ccb=1-7&_nc_sid=3ab345&_nc_ohc=7UR6Xa9SM_YQ7kNvwHFraK4&_nc_oc=AdkDwGrSyPdiE2NVrWQmFfcryZCB3CNnwN8PsGWpMvSoOkcPlfKRFpAhBs_4riCNAl4&_nc_zt=24&_nc_ht=scontent-ams2-1.xx&_nc_gid=b5WzTG_v1UJTEuHKcrlykQ&oh=00_AfhjM7e7aEqG0R5vHkqLngxMvxGxcf0EPlw8awiGgtFmDA&oe=693D89DD",
#   "og:locale": "en_US"
# }

# %% [markdown]
# ### Task 3.2
# Explore the various microformats at http://microformats.org/ and compare the output of the exercises with the output of http://microformats.org/. Think about possible microformats you want to support in your final assignment and read up on how to parse them.

# %%
from mf2py.parser import Parser
import requests, json

# Microformat Example: h-card
html = """
<div class="h-card">
  <p class="p-name">Example Name</p>
  <a class="u-url" href="https://examplesite.com">Example Website</a>
  <p class="p-locality">Amsterdam</p>
</div>
"""

parsed = Parser(doc=html).to_dict()

# Output from Microformats.org
url = "https://microformats.org/wiki/h-card"
html_from_site = requests.get(url).text

parsed_site = Parser(doc=html_from_site).to_dict()

print("Example Output")
print(json.dumps(parsed, indent=2))
print("Output from Microformats.org")
print(json.dumps(parsed_site, indent=2))

print("------------------------------------------------------------------")

# Microformat Example: h-event
html_event = """
<div class="h-event">
  <h2 class="p-name">Example Event</h2>
  <p>
    <time class="dt-start" datetime="2025-11-12T19:00">Nov 12, 2025, 7PM</time>
    at <span class="p-location">Example Cafe</span>
  </p>
  <p class="p-description">Coffee house hosting a wonderful open evening.</p>
</div>
"""

parsed_event = Parser(doc=html_event).to_dict()

# Output from Microformats.org
url_event = "https://microformats.org/wiki/h-event"
html_from_site_event = requests.get(url_event).text
parsed_site_event = Parser(doc=html_from_site_event).to_dict()

print("Example Output")
print(json.dumps(parsed_event, indent=2))
print("Output from Microformats.org")
print(json.dumps(parsed_site_event, indent=2))

print("------------------------------------------------------------------")

# Microformat Example: h-entry
html_entry = """
<article class="h-entry">
  <h1 class="p-name">Example Class</h1>
  <a class="u-url" href="https://examplesite.com/">Example note</a>
  <p class="p-author h-card">
    <span class="p-name">Example Author</span>
  </p>
  <time class="dt-published" datetime="2025-11-10">November 10, 2025</time>
  <div class="e-content">
    <p>Example paragprah containing article content!</p>
  </div>
</article>
"""

parsed_entry = Parser(doc=html_entry).to_dict()

# Output from Microformats.org
url_entry = "https://microformats.org/wiki/h-entry"
html_from_site_entry = requests.get(url_entry).text
parsed_site_entry = Parser(doc=html_from_site_entry).to_dict()

print("Example Output")
print(json.dumps(parsed_entry, indent=2))
print("Output from Microformats.org")
print(json.dumps(parsed_site_entry, indent=2))

# With visual comparison, the example formats are very similar to the actual format of the output from Microformats.org, 
# but naturally the actual output contains a lot more information, especially as one block can contain many sub-blocks.
# The example formats show the simplest case, so it makes sense that actual implementations would be more complicated.
# Out:
# Example Output
# {
#   "items": [
#     {
#       "type": [
#         "h-card"
#       ],
#       "properties": {
#         "name": [
#           "Example Name"
#         ],
#         "url": [
#           "https://examplesite.com"
#         ],
#         "locality": [
#           "Amsterdam"
#         ]
#       }
#     }
#   ],
#   "rels": {},
#   "rel-urls": {},
#   "debug": {
#     "description": "mf2py - microformats2 parser for python",
#     "source": "https://github.com/microformats/mf2py",
#     "version": "2.0.1",
#     "markup parser": "html5lib"
#   }
# }
# Output from Microformats.org
# {
#   "items": [
#     {
#       "type": [
#         "h-card"
#       ],
#       "properties": {
#         "role": [
#           "Editor"
#         ],
#         "name": [
#           "Tantek \u00c7elik"
#         ]
#       },
#       "lang": "en"
#     }
#   ],
#   "rels": {
#     "stylesheet": [
#       "/wiki/load.php?lang=en&modules=ext.pygments%7Cskins.vector.styles.legacy&only=styles&skin=vector"
#     ],
#     "shortcut": [
#       "/favicon.ico"
#     ],
#     "icon": [
#       "/favicon.ico"
#     ],
#     "search": [
#       "/wiki/opensearch_desc.php"
#     ],
#     "EditURI": [
#       "//microformats.org/wiki/api.php?action=rsd"
#     ],
#     "alternate": [
#       "/wiki/index.php?title=Special:RecentChanges&feed=atom",
#       "javascript:print();"
#     ],
#     "nofollow": [
#       "https://github.com/microformats/h-card/issues",
#       "http://creativecommons.org/publicdomain/zero/1.0/",
#       "https://www.openwebfoundation.org/the-agreements/the-owf-1-0-agreements-granted-claims/owfa-1-0",
#       "https://vanderven.se/martijn/",
#       "https://chat.indieweb.org/microformats",
#       "https://tools.ietf.org/html/rfc6350#section-4.3.1",
#       "https://chat.indieweb.org/microformats/2021-06-22/1624385751126500",
#       "https://indieweb.org/h-card#IndieWeb_Examples",
#       "http://www.securityjobslondon.co.uk",
#       "https://search.google.com/structured-data/testing-tool",
#       "http://bret.io/2013/06/29/getting-started-with-bower/",
#       "http://werd.io/view/51d5097fbed7ded0633a5956",
#       "https://joelpurra.com/",
#       "http://eschnou.com/",
#       "http://tommorris.org/",
#       "http://tommorris.org/posts/8408",
#       "https://www.w3.org/conf/",
#       "http://wordpress.org/extend/themes/sempress",
#       "http://the-pastry-box-project.net/",
#       "http://tommorris.org/pages/blogroll",
#       "https://aaronparecki.com/2012/230/reply/1",
#       "https://tantek.com/",
#       "http://waterpigs.co.uk/",
#       "https://tantek.com/presentations/2012/06/microformats",
#       "https://tantek.com/presentations/2012/06/pdf2012-indieweb.html",
#       "https://webmaker.org/en-US/events/near/?lat=45.5234515&lng=-122.6762071",
#       "https://webmaker.org/en-US/events/192f56eb9/",
#       "https://twitter.com/microformats/status/212207925643587585",
#       "https://webfwd.org/about/experts/",
#       "https://webfwd.org/about/team/",
#       "https://indiewebcamp.com",
#       "https://wiki.mozilla.org/Events",
#       "https://tristanthomas.me",
#       "http://cold32.com/about-the-author-and-contact.htm",
#       "https://workfrom.co/",
#       "https://workfrom.co/palio-dessert-and-espresso-house",
#       "http://www.pcwdld.com/",
#       "http://www.pcwdld.com/solarwinds-network-topology-mapper-review",
#       "https://alpha.app.net/voidfiles",
#       "https://sandeep.io/101",
#       "https://indiewebify.me/validate-h-card/",
#       "https://pin13.net/mf2/",
#       "https://pin13.net/",
#       "https://indieweb.org/",
#       "https://gnu.io/social/",
#       "https://git.gnu.io/gnu/gnu-social/",
#       "https://hubzilla.org/hubzilla/",
#       "https://github.org/redmatrix/hubzilla",
#       "http://friendica.com/",
#       "https://github.org/friendica/friendica",
#       "https://github.com/dissolve/inkblot",
#       "https://aperture.p3k.io/",
#       "https://github.com/aaronpk/Aperture/",
#       "https://xray.p3k.app/",
#       "https://github.com/aaronpk/XRay/",
#       "https://withknown.com/",
#       "https://brid.gy/",
#       "https://webmention.io/",
#       "http://microformats.org",
#       "/wiki/Special:RecentChangesLinked/h-card"
#     ],
#     "discussion": [
#       "/wiki/index.php?title=Talk:h-card&action=edit&redlink=1"
#     ]
#   },
#   "rel-urls": {
#     "/wiki/load.php?lang=en&modules=ext.pygments%7Cskins.vector.styles.legacy&only=styles&skin=vector": {
#       "text": "",
#       "rels": [
#         "stylesheet"
#       ]
#     },
#     "/favicon.ico": {
#       "text": "",
#       "rels": [
#         "icon",
#         "shortcut"
#       ]
#     },
#     "/wiki/opensearch_desc.php": {
#       "text": "",
#       "rels": [
#         "search"
#       ],
#       "type": "application/opensearchdescription+xml",
#       "title": "Microformats Wiki (en)"
#     },
#     "//microformats.org/wiki/api.php?action=rsd": {
#       "text": "",
#       "rels": [
#         "EditURI"
#       ],
#       "type": "application/rsd+xml"
#     },
#     "/wiki/index.php?title=Special:RecentChanges&feed=atom": {
#       "text": "",
#       "rels": [
#         "alternate"
#       ],
#       "type": "application/atom+xml",
#       "title": "Microformats Wiki Atom feed"
#     },
#     "https://github.com/microformats/h-card/issues": {
#       "text": "feedback",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "http://creativecommons.org/publicdomain/zero/1.0/": {
#       "text": "CC0",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://www.openwebfoundation.org/the-agreements/the-owf-1-0-agreements-granted-claims/owfa-1-0": {
#       "text": "Open Web Foundation Agreement Version 1.0",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://vanderven.se/martijn/": {
#       "text": "Martijn van der Ven",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://chat.indieweb.org/microformats": {
#       "text": "view recent discussions",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://tools.ietf.org/html/rfc6350#section-4.3.1": {
#       "text": "the vcard spec",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://chat.indieweb.org/microformats/2021-06-22/1624385751126500": {
#       "text": "tantek in #microformats",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://indieweb.org/h-card#IndieWeb_Examples": {
#       "text": "h-card Examples on indieweb.org",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "http://www.securityjobslondon.co.uk": {
#       "text": "Security Jobs London",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://search.google.com/structured-data/testing-tool": {
#       "text": "Google's Structured Data Testing Tool",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "http://bret.io/2013/06/29/getting-started-with-bower/": {
#       "text": "example",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "http://werd.io/view/51d5097fbed7ded0633a5956": {
#       "text": "example",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://joelpurra.com/": {
#       "text": "Joel Purra",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "http://eschnou.com/": {
#       "text": "Laurent Eschenauer",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "http://tommorris.org/": {
#       "text": "Tom Morris",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "http://tommorris.org/posts/8408": {
#       "text": "example",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://www.w3.org/conf/": {
#       "text": "W3Conf 2013",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "http://wordpress.org/extend/themes/sempress": {
#       "text": "SemPress",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "http://the-pastry-box-project.net/": {
#       "text": "The Pastry Box Project",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "http://tommorris.org/pages/blogroll": {
#       "text": "his blogroll",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://aaronparecki.com/2012/230/reply/1": {
#       "text": "2012/230/reply/1",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://tantek.com/": {
#       "text": "Tantek \u00c7elik",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "http://waterpigs.co.uk/": {
#       "text": "Barnaby Walters",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://tantek.com/presentations/2012/06/microformats": {
#       "text": "microformats.org at 7 years",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://tantek.com/presentations/2012/06/pdf2012-indieweb.html": {
#       "text": "Rise of the Indie Web hCards",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://webmaker.org/en-US/events/near/?lat=45.5234515&lng=-122.6762071": {
#       "text": "search near Portland Oregon",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://webmaker.org/en-US/events/192f56eb9/": {
#       "text": "IndieWebCamp 2012",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://twitter.com/microformats/status/212207925643587585": {
#       "text": "[1]",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://webfwd.org/about/experts/": {
#       "text": "experts",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://webfwd.org/about/team/": {
#       "text": "team",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://indiewebcamp.com": {
#       "text": "IndieWebCamp",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://wiki.mozilla.org/Events": {
#       "text": "Mozilla Events",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://tristanthomas.me": {
#       "text": "Tristan Thomas",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "http://cold32.com/about-the-author-and-contact.htm": {
#       "text": "Cold32.com",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://workfrom.co/": {
#       "text": "Workfrom.co",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://workfrom.co/palio-dessert-and-espresso-house": {
#       "text": "[2]",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "http://www.pcwdld.com/": {
#       "text": "PCWDLD.com",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "http://www.pcwdld.com/solarwinds-network-topology-mapper-review": {
#       "text": "Download page example",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://alpha.app.net/voidfiles": {
#       "text": "example",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://sandeep.io/101": {
#       "text": "example",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://indiewebify.me/validate-h-card/": {
#       "text": "indiewebify.me h-card validator",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://pin13.net/mf2/": {
#       "text": "https://pin13.net/mf2/",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://pin13.net/": {
#       "text": "https://pin13.net/",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://indieweb.org/": {
#       "text": "indie web",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://gnu.io/social/": {
#       "text": "GNUsocial",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://git.gnu.io/gnu/gnu-social/": {
#       "text": "source code",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://hubzilla.org/hubzilla/": {
#       "text": "Hubzilla",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://github.org/redmatrix/hubzilla": {
#       "text": "source code",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "http://friendica.com/": {
#       "text": "Friendica",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://github.org/friendica/friendica": {
#       "text": "source code",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://github.com/dissolve/inkblot": {
#       "text": "InkBlot",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://aperture.p3k.io/": {
#       "text": "Aperture",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://github.com/aaronpk/Aperture/": {
#       "text": "source code",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://xray.p3k.app/": {
#       "text": "XRay",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://github.com/aaronpk/XRay/": {
#       "text": "source code",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://withknown.com/": {
#       "text": "Known",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://brid.gy/": {
#       "text": "Bridgy",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://webmention.io/": {
#       "text": "webmention.io",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "/wiki/index.php?title=Talk:h-card&action=edit&redlink=1": {
#       "text": "Discussion",
#       "rels": [
#         "discussion"
#       ],
#       "title": "Discussion about the content page (page does not exist) [t]"
#     },
#     "http://microformats.org": {
#       "text": "Blog",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "/wiki/Special:RecentChangesLinked/h-card": {
#       "text": "Related changes",
#       "rels": [
#         "nofollow"
#       ],
#       "title": "Recent changes in pages linked from this page [k]"
#     },
#     "javascript:print();": {
#       "text": "Printable version",
#       "rels": [
#         "alternate"
#       ],
#       "title": "Printable version of this page [p]"
#     }
#   },
#   "debug": {
#     "description": "mf2py - microformats2 parser for python",
#     "source": "https://github.com/microformats/mf2py",
#     "version": "2.0.1",
#     "markup parser": "html5lib"
#   },
#   "alternates": [
#     {
#       "url": "/wiki/index.php?title=Special:RecentChanges&feed=atom",
#       "text": "",
#       "type": "application/atom+xml",
#       "title": "Microformats Wiki Atom feed"
#     },
#     {
#       "url": "javascript:print();",
#       "text": "Printable version",
#       "title": "Printable version of this page [p]"
#     }
#   ]
# }
# ------------------------------------------------------------------
# Example Output
# {
#   "items": [
#     {
#       "type": [
#         "h-event"
#       ],
#       "properties": {
#         "name": [
#           "Example Event"
#         ],
#         "start": [
#           "2025-11-12T19:00"
#         ],
#         "location": [
#           "Example Cafe"
#         ],
#         "description": [
#           "Coffee house hosting a wonderful open evening."
#         ]
#       }
#     }
#   ],
#   "rels": {},
#   "rel-urls": {},
#   "debug": {
#     "description": "mf2py - microformats2 parser for python",
#     "source": "https://github.com/microformats/mf2py",
#     "version": "2.0.1",
#     "markup parser": "html5lib"
#   }
# }
# Output from Microformats.org
# {
#   "items": [
#     {
#       "type": [
#         "h-card"
#       ],
#       "properties": {
#         "role": [
#           "Editor"
#         ],
#         "name": [
#           "Tantek \u00c7elik"
#         ]
#       },
#       "lang": "en"
#     }
#   ],
#   "rels": {
#     "stylesheet": [
#       "/wiki/load.php?lang=en&modules=ext.pygments%7Cskins.vector.styles.legacy&only=styles&skin=vector"
#     ],
#     "shortcut": [
#       "/favicon.ico"
#     ],
#     "icon": [
#       "/favicon.ico"
#     ],
#     "search": [
#       "/wiki/opensearch_desc.php"
#     ],
#     "EditURI": [
#       "//microformats.org/wiki/api.php?action=rsd"
#     ],
#     "alternate": [
#       "/wiki/index.php?title=Special:RecentChanges&feed=atom",
#       "javascript:print();"
#     ],
#     "nofollow": [
#       "https://github.com/microformats/h-event/issues",
#       "https://github.com/microformats/h-event/issues/1",
#       "http://creativecommons.org/publicdomain/zero/1.0/",
#       "https://www.openwebfoundation.org/the-agreements/the-owf-1-0-agreements-granted-claims/owfa-1-0",
#       "https://github.com/microformats/h-event/issues/3",
#       "https://github.com/microformats/h-event/issues/2",
#       "https://github.com/microformats/h-event/issues/10",
#       "https://github.com/microformats/h-event/issues/9",
#       "https://chat.indieweb.org/microformats",
#       "https://github.com/snarfed/bridgy/issues/275",
#       "http://www.w3.org/conf/",
#       "http://tantek.com/",
#       "http://tantek.com/presentations/2012/06/microformats",
#       "http://tantek.com/presentations/2012/06/pdf2012-indieweb.html",
#       "https://webmaker.org/en-US/events/near/?lat=45.5234515&lng=-122.6762071",
#       "https://webmaker.org/en-US/events/192f56eb9/",
#       "https://twitter.com/microformats/status/212207925643587585",
#       "http://indiewebcamp.com",
#       "https://wiki.mozilla.org/Events",
#       "https://gregorlove.com/events",
#       "https://gregorlove.com/2017/06/homebrew-website-club/",
#       "https://oauth.net/events/",
#       "http://68middle.st/events",
#       "https://www.gov.uk/government/publications/open-standards-for-government/exchange-of-calendar-events",
#       "https://pin13.net/mf2/",
#       "https://pin13.net/",
#       "https://github.com/gRegorLove/mf2-to-iCalendar",
#       "https://gregorlove.com/calendar/",
#       "http://microformats.org",
#       "/wiki/Special:RecentChangesLinked/h-event"
#     ],
#     "discussion": [
#       "/wiki/index.php?title=Talk:h-event&action=edit&redlink=1"
#     ]
#   },
#   "rel-urls": {
#     "/wiki/load.php?lang=en&modules=ext.pygments%7Cskins.vector.styles.legacy&only=styles&skin=vector": {
#       "text": "",
#       "rels": [
#         "stylesheet"
#       ]
#     },
#     "/favicon.ico": {
#       "text": "",
#       "rels": [
#         "icon",
#         "shortcut"
#       ]
#     },
#     "/wiki/opensearch_desc.php": {
#       "text": "",
#       "rels": [
#         "search"
#       ],
#       "type": "application/opensearchdescription+xml",
#       "title": "Microformats Wiki (en)"
#     },
#     "//microformats.org/wiki/api.php?action=rsd": {
#       "text": "",
#       "rels": [
#         "EditURI"
#       ],
#       "type": "application/rsd+xml"
#     },
#     "/wiki/index.php?title=Special:RecentChanges&feed=atom": {
#       "text": "",
#       "rels": [
#         "alternate"
#       ],
#       "type": "application/atom+xml",
#       "title": "Microformats Wiki Atom feed"
#     },
#     "https://github.com/microformats/h-event/issues": {
#       "text": "feedback",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://github.com/microformats/h-event/issues/1": {
#       "text": "issue: adopt same change control as h-entry",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "http://creativecommons.org/publicdomain/zero/1.0/": {
#       "text": "CC0",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://www.openwebfoundation.org/the-agreements/the-owf-1-0-agreements-granted-claims/owfa-1-0": {
#       "text": "Open Web Foundation Agreement Version 1.0",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://github.com/microformats/h-event/issues/3": {
#       "text": "https://github.com/microformats/h-event/issues/3",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://github.com/microformats/h-event/issues/2": {
#       "text": "https://github.com/microformats/h-event/issues/2",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://github.com/microformats/h-event/issues/10": {
#       "text": "https://github.com/microformats/h-event/issues/10",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://github.com/microformats/h-event/issues/9": {
#       "text": "https://github.com/microformats/h-event/issues/9",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://chat.indieweb.org/microformats": {
#       "text": "view recent discussions",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://github.com/snarfed/bridgy/issues/275": {
#       "text": "implement copying an event organizer to Eventbrite",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "http://www.w3.org/conf/": {
#       "text": "W3Conf 2013",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "http://tantek.com/": {
#       "text": "Tantek \u00c7elik",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "http://tantek.com/presentations/2012/06/microformats": {
#       "text": "microformats.org at 7 years",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "http://tantek.com/presentations/2012/06/pdf2012-indieweb.html": {
#       "text": "Rise of the Indie Web hCards",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://webmaker.org/en-US/events/near/?lat=45.5234515&lng=-122.6762071": {
#       "text": "search near Portland Oregon",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://webmaker.org/en-US/events/192f56eb9/": {
#       "text": "IndieWebCamp 2012",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://twitter.com/microformats/status/212207925643587585": {
#       "text": "[1]",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "http://indiewebcamp.com": {
#       "text": "IndieWebCamp",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://wiki.mozilla.org/Events": {
#       "text": "Mozilla Events",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://gregorlove.com/events": {
#       "text": "https://gregorlove.com/events",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://gregorlove.com/2017/06/homebrew-website-club/": {
#       "text": "https://gregorlove.com/2017/06/homebrew-website-club/",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://oauth.net/events/": {
#       "text": "https://oauth.net/events/",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "http://68middle.st/events": {
#       "text": "http://68middle.st/events",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://www.gov.uk/government/publications/open-standards-for-government/exchange-of-calendar-events": {
#       "text": "gov.uk",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://pin13.net/mf2/": {
#       "text": "https://pin13.net/mf2/",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://pin13.net/": {
#       "text": "https://pin13.net/",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://github.com/gRegorLove/mf2-to-iCalendar": {
#       "text": "mf2 to iCalendar",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://gregorlove.com/calendar/": {
#       "text": "https://gregorlove.com/calendar/",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "/wiki/index.php?title=Talk:h-event&action=edit&redlink=1": {
#       "text": "Discussion",
#       "rels": [
#         "discussion"
#       ],
#       "title": "Discussion about the content page (page does not exist) [t]"
#     },
#     "http://microformats.org": {
#       "text": "Blog",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "/wiki/Special:RecentChangesLinked/h-event": {
#       "text": "Related changes",
#       "rels": [
#         "nofollow"
#       ],
#       "title": "Recent changes in pages linked from this page [k]"
#     },
#     "javascript:print();": {
#       "text": "Printable version",
#       "rels": [
#         "alternate"
#       ],
#       "title": "Printable version of this page [p]"
#     }
#   },
#   "debug": {
#     "description": "mf2py - microformats2 parser for python",
#     "source": "https://github.com/microformats/mf2py",
#     "version": "2.0.1",
#     "markup parser": "html5lib"
#   },
#   "alternates": [
#     {
#       "url": "/wiki/index.php?title=Special:RecentChanges&feed=atom",
#       "text": "",
#       "type": "application/atom+xml",
#       "title": "Microformats Wiki Atom feed"
#     },
#     {
#       "url": "javascript:print();",
#       "text": "Printable version",
#       "title": "Printable version of this page [p]"
#     }
#   ]
# }
# ------------------------------------------------------------------
# Example Output
# {
#   "items": [
#     {
#       "type": [
#         "h-entry"
#       ],
#       "properties": {
#         "name": [
#           "Example Class"
#         ],
#         "url": [
#           "https://examplesite.com/"
#         ],
#         "author": [
#           {
#             "type": [
#               "h-card"
#             ],
#             "properties": {
#               "name": [
#                 "Example Author"
#               ]
#             },
#             "value": "Example Author"
#           }
#         ],
#         "published": [
#           "2025-11-10"
#         ],
#         "content": [
#           {
#             "value": "Example paragprah containing article content!",
#             "html": "<p>Example paragprah containing article content!</p>"
#           }
#         ]
#       }
#     }
#   ],
#   "rels": {},
#   "rel-urls": {},
#   "debug": {
#     "description": "mf2py - microformats2 parser for python",
#     "source": "https://github.com/microformats/mf2py",
#     "version": "2.0.1",
#     "markup parser": "html5lib"
#   }
# }
# Output from Microformats.org
# {
#   "items": [
#     {
#       "type": [
#         "h-card"
#       ],
#       "properties": {
#         "role": [
#           "Editor"
#         ],
#         "name": [
#           "Tantek \u00c7elik"
#         ]
#       },
#       "lang": "en"
#     }
#   ],
#   "rels": {
#     "stylesheet": [
#       "/wiki/load.php?lang=en&modules=ext.pygments%7Cskins.vector.styles.legacy&only=styles&skin=vector"
#     ],
#     "shortcut": [
#       "/favicon.ico"
#     ],
#     "icon": [
#       "/favicon.ico"
#     ],
#     "search": [
#       "/wiki/opensearch_desc.php"
#     ],
#     "EditURI": [
#       "//microformats.org/wiki/api.php?action=rsd"
#     ],
#     "alternate": [
#       "/wiki/index.php?title=Special:RecentChanges&feed=atom",
#       "javascript:print();"
#     ],
#     "nofollow": [
#       "https://github.com/microformats/h-entry/issues",
#       "http://creativecommons.org/publicdomain/zero/1.0/",
#       "https://www.openwebfoundation.org/the-agreements/the-owf-1-0-agreements-granted-claims/owfa-1-0",
#       "https://web.archive.org/web/20141027120218/http://erinjo.is:80/2014/checked-into-rockit-colabs-23",
#       "http://indiewebcamp.com/reply-context",
#       "https://kartikprabhu.com/notes/re-citizen-of-indieweb",
#       "http://waterpigs.co.uk/notes/4V2DjG/",
#       "https://github.com/microformats/h-entry/issues/20",
#       "https://github.com/microformats/h-entry/issues/4",
#       "https://github.com/microformats/h-entry/issues/24",
#       "https://github.com/microformats/h-entry/issues/23",
#       "https://github.com/microformats/h-entry/issues/5",
#       "http://transportini.com/",
#       "https://indieweb.org/podcast#How_to_podcast_with_h-feed",
#       "https://github.com/microformats/h-entry/issues/6",
#       "https://github.com/microformats/h-entry/issues/31",
#       "https://github.com/microformats/h-entry/issues/30",
#       "https://indieweb.org/bookmark",
#       "https://github.com/microformats/h-entry/issues/12",
#       "https://github.com/microformats/h-entry/issues/14",
#       "https://github.com/microformats/h-entry/issues/29",
#       "https://indieweb.org/duration",
#       "https://github.com/snarfed/granary/issues/169",
#       "https://github.com/microformats/h-entry/issues/21",
#       "https://indieweb.org/size",
#       "https://github.com/microformats/h-entry/issues/11",
#       "https://github.com/microformats/h-entry/issues/17",
#       "https://github.com/microformats/h-entry/issues/10",
#       "https://github.com/microformats/h-entry/issues/26",
#       "https://github.com/microformats/h-entry/issues/15",
#       "https://github.com/microformats/h-entry/issues/32",
#       "https://aaronparecki.com/2017/01/13/21/",
#       "https://indieweb.org/note",
#       "https://ind.ie/blog",
#       "https://ind.ie/blog/autumn-events-2014/",
#       "http://davidjohnmead.com",
#       "http://optional.is/required/",
#       "http://acegiak.net/",
#       "http://notenoughneon.com/",
#       "http://jenson.org/",
#       "http://blackwoolholiday.com/",
#       "https://snarfed.org/",
#       "http://barryfrost.com/",
#       "http://caseorganic.com/",
#       "http://upon2020.com/blog/",
#       "https://michielbdejong.com/",
#       "https://bear.im/bearlog/",
#       "https://jeena.net/",
#       "http://andysylvester.com/2014/03/01/howto-setting-up-the-selfoss-feed-reader-with-microformats-support/",
#       "http://chloeweil.com/blog",
#       "http://christopheducamp.com/",
#       "http://glennjones.net/",
#       "http://www.marcus-povey.co.uk/",
#       "http://notizblog.org/",
#       "http://www.okinawan-lyrics.com/",
#       "https://alpha.app.net/voidfiles",
#       "http://bret.io/2013/06/29/getting-started-with-bower/",
#       "http://werd.io/view/51d5097fbed7ded0633a5956",
#       "http://sandeep.io/101",
#       "http://eschnou.com/entry/first-autonomous-flight-of-my-nodecopter-62-24992.html",
#       "http://tommorris.org/posts/8417",
#       "http://www.w3.org/TR/2013/CR-css3-values-20130404/",
#       "http://www.w3.org/TR/2013/CR-css3-conditional-20130404/",
#       "http://www.w3.org/TR/2013/WD-css3-page-20130314/",
#       "http://www.w3.org/TR/2013/WD-css-counter-styles-3-20130221/",
#       "http://wordpress.org/extend/themes/sempress",
#       "http://the-pastry-box-project.net/",
#       "http://aaronparecki.com/2012/230/reply/1",
#       "http://tantek.com/",
#       "http://tantek.com/2012/243/t1/name-beats-title-modern-use-dubline-core-wrong-uf2",
#       "http://waterpigs.co.uk/",
#       "http://waterpigs.co.uk/notes/1468/",
#       "http://waterpigs.co.uk/notes/1482/",
#       "http://indiewebify.me/validate-h-entry/",
#       "http://shrewdness.waterpigs.co.uk/test/",
#       "https://pin13.net/mf2/",
#       "https://pin13.net/",
#       "https://indieweb.org/",
#       "https://gnu.io/social/",
#       "https://git.gnu.io/gnu/gnu-social/",
#       "https://hubzilla.org/hubzilla/",
#       "https://github.org/redmatrix/hubzilla",
#       "http://friendica.com/",
#       "https://github.org/friendica/friendica",
#       "http://github.com/dissolve/inkblot",
#       "https://github.com/microformats/h-entry/issues/7",
#       "https://wp-themes.com/twentyeleven/",
#       "https://wp-themes.com/twentytwelve/",
#       "https://wp-themes.com/twentythirteen/",
#       "https://wp-themes.com/twentyfourteen/",
#       "http://www.whatwg.org/specs/web-apps/current-work/multipage/links.html#link-type-bookmark",
#       "http://krijnhoetmer.nl/irc-logs/microformats/20120830#l-128",
#       "https://mailpile.pagekite.me:8080/p/Open_Message_Format",
#       "http://indiewebcamp.com",
#       "http://microformats.org",
#       "/wiki/Special:RecentChangesLinked/h-entry"
#     ],
#     "discussion": [
#       "/wiki/index.php?title=Talk:h-entry&action=edit&redlink=1"
#     ]
#   },
#   "rel-urls": {
#     "/wiki/load.php?lang=en&modules=ext.pygments%7Cskins.vector.styles.legacy&only=styles&skin=vector": {
#       "text": "",
#       "rels": [
#         "stylesheet"
#       ]
#     },
#     "/favicon.ico": {
#       "text": "",
#       "rels": [
#         "icon",
#         "shortcut"
#       ]
#     },
#     "/wiki/opensearch_desc.php": {
#       "text": "",
#       "rels": [
#         "search"
#       ],
#       "type": "application/opensearchdescription+xml",
#       "title": "Microformats Wiki (en)"
#     },
#     "//microformats.org/wiki/api.php?action=rsd": {
#       "text": "",
#       "rels": [
#         "EditURI"
#       ],
#       "type": "application/rsd+xml"
#     },
#     "/wiki/index.php?title=Special:RecentChanges&feed=atom": {
#       "text": "",
#       "rels": [
#         "alternate"
#       ],
#       "type": "application/atom+xml",
#       "title": "Microformats Wiki Atom feed"
#     },
#     "https://github.com/microformats/h-entry/issues": {
#       "text": "Open Issues",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "http://creativecommons.org/publicdomain/zero/1.0/": {
#       "text": "CC0",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://www.openwebfoundation.org/the-agreements/the-owf-1-0-agreements-granted-claims/owfa-1-0": {
#       "text": "Open Web Foundation Agreement Version 1.0",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://web.archive.org/web/20141027120218/http://erinjo.is:80/2014/checked-into-rockit-colabs-23": {
#       "text": "archived example",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "http://indiewebcamp.com/reply-context": {
#       "text": "reply-context",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://kartikprabhu.com/notes/re-citizen-of-indieweb": {
#       "text": "example",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "http://waterpigs.co.uk/notes/4V2DjG/": {
#       "text": "example",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://github.com/microformats/h-entry/issues/20": {
#       "text": "Issue 20",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://github.com/microformats/h-entry/issues/4": {
#       "text": "Issue 4: u-photo draft->core bc way more than 3+ pub and consuming impls/sites",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://github.com/microformats/h-entry/issues/24": {
#       "text": "Issue 24: Update Definition of Draft Property u-photo",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://github.com/microformats/h-entry/issues/23": {
#       "text": "Issue 23: E-Content Overlaps with u-photo and similar properties",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://github.com/microformats/h-entry/issues/5": {
#       "text": "Issue 5",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "http://transportini.com/": {
#       "text": "Transportini",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://indieweb.org/podcast#How_to_podcast_with_h-feed": {
#       "text": "possibly more",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://github.com/microformats/h-entry/issues/6": {
#       "text": "Issue 6",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://github.com/microformats/h-entry/issues/31": {
#       "text": "Issue 32",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://github.com/microformats/h-entry/issues/30": {
#       "text": "Issue 30",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://indieweb.org/bookmark": {
#       "text": "indieweb.org/bookmark",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://github.com/microformats/h-entry/issues/12": {
#       "text": "Issue 12",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://github.com/microformats/h-entry/issues/14": {
#       "text": "https://github.com/microformats/h-entry/issues/14",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://github.com/microformats/h-entry/issues/29": {
#       "text": "https://github.com/microformats/h-entry/issues/29",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://indieweb.org/duration": {
#       "text": "https://indieweb.org/duration",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://github.com/snarfed/granary/issues/169": {
#       "text": "https://github.com/snarfed/granary/issues/169",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://github.com/microformats/h-entry/issues/21": {
#       "text": "Issue 21",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://indieweb.org/size": {
#       "text": "https://indieweb.org/size",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://github.com/microformats/h-entry/issues/11": {
#       "text": "https://github.com/microformats/h-entry/issues/11",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://github.com/microformats/h-entry/issues/17": {
#       "text": "https://github.com/microformats/h-entry/issues/17",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://github.com/microformats/h-entry/issues/10": {
#       "text": "https://github.com/microformats/h-entry/issues/10",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://github.com/microformats/h-entry/issues/26": {
#       "text": "https://github.com/microformats/h-entry/issues/26",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://github.com/microformats/h-entry/issues/15": {
#       "text": "https://github.com/microformats/h-entry/issues/15",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://github.com/microformats/h-entry/issues/32": {
#       "text": "Issue 32",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://aaronparecki.com/2017/01/13/21/": {
#       "text": "this post",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://indieweb.org/note": {
#       "text": "note",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://ind.ie/blog": {
#       "text": "blog",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://ind.ie/blog/autumn-events-2014/": {
#       "text": "permalink",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "http://davidjohnmead.com": {
#       "text": "davidjohnmead.com",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "http://optional.is/required/": {
#       "text": "optional.is",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "http://acegiak.net/": {
#       "text": "acegiak.net",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "http://notenoughneon.com/": {
#       "text": "notenoughneon.com",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "http://jenson.org/": {
#       "text": "jenson.org",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "http://blackwoolholiday.com/": {
#       "text": "blackwoolholiday.com",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://snarfed.org/": {
#       "text": "snarfed.org",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "http://barryfrost.com/": {
#       "text": "barryfrost.com",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "http://caseorganic.com/": {
#       "text": "caseorganic.com",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "http://upon2020.com/blog/": {
#       "text": "upon2020.com",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://michielbdejong.com/": {
#       "text": "michielbdejong.com",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://bear.im/bearlog/": {
#       "text": "bear.im",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://jeena.net/": {
#       "text": "jeena.net",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "http://andysylvester.com/2014/03/01/howto-setting-up-the-selfoss-feed-reader-with-microformats-support/": {
#       "text": "andysylvester.com",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "http://chloeweil.com/blog": {
#       "text": "chloeweil.com",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "http://christopheducamp.com/": {
#       "text": "christopheducamp.com",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "http://glennjones.net/": {
#       "text": "glennjones.net",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "http://www.marcus-povey.co.uk/": {
#       "text": "marcus-povey.co.uk",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "http://notizblog.org/": {
#       "text": "notizblog.org",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "http://www.okinawan-lyrics.com/": {
#       "text": "example",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://alpha.app.net/voidfiles": {
#       "text": "example",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "http://bret.io/2013/06/29/getting-started-with-bower/": {
#       "text": "example",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "http://werd.io/view/51d5097fbed7ded0633a5956": {
#       "text": "example",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "http://sandeep.io/101": {
#       "text": "example",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "http://eschnou.com/entry/first-autonomous-flight-of-my-nodecopter-62-24992.html": {
#       "text": "example",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "http://tommorris.org/posts/8417": {
#       "text": "example",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "http://www.w3.org/TR/2013/CR-css3-values-20130404/": {
#       "text": "CSS Values and Units Module Level 3 - 2013-04-04",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "http://www.w3.org/TR/2013/CR-css3-conditional-20130404/": {
#       "text": "CSS Conditional Rules Module Level 3 - 2013-04-04",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "http://www.w3.org/TR/2013/WD-css3-page-20130314/": {
#       "text": "CSS Paged Media Module Level 3 - 2013-03-14",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "http://www.w3.org/TR/2013/WD-css-counter-styles-3-20130221/": {
#       "text": "CSS Counter Styles Level 3 - 2013-02-21",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "http://wordpress.org/extend/themes/sempress": {
#       "text": "SemPress",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "http://the-pastry-box-project.net/": {
#       "text": "The Pastry Box Project",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "http://aaronparecki.com/2012/230/reply/1": {
#       "text": "2012/230/reply/1",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "http://tantek.com/": {
#       "text": "Tantek \u00c7elik",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "http://tantek.com/2012/243/t1/name-beats-title-modern-use-dubline-core-wrong-uf2": {
#       "text": "2012-243 post",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "http://waterpigs.co.uk/": {
#       "text": "Barnaby Walters",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "http://waterpigs.co.uk/notes/1468/": {
#       "text": "example",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "http://waterpigs.co.uk/notes/1482/": {
#       "text": "example",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "http://indiewebify.me/validate-h-entry/": {
#       "text": "indiewebify.me h-entry validator",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "http://shrewdness.waterpigs.co.uk/test/": {
#       "text": "Shrewdness h-entry/h-feed validator",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://pin13.net/mf2/": {
#       "text": "https://pin13.net/mf2/",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://pin13.net/": {
#       "text": "https://pin13.net/",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://indieweb.org/": {
#       "text": "indie web",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://gnu.io/social/": {
#       "text": "GNUsocial",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://git.gnu.io/gnu/gnu-social/": {
#       "text": "source code",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://hubzilla.org/hubzilla/": {
#       "text": "Hubzilla",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://github.org/redmatrix/hubzilla": {
#       "text": "source code",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "http://friendica.com/": {
#       "text": "Friendica",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://github.org/friendica/friendica": {
#       "text": "source code",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "http://github.com/dissolve/inkblot": {
#       "text": "InkBlot",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://github.com/microformats/h-entry/issues/7": {
#       "text": "follow-up in issue #7",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://wp-themes.com/twentyeleven/": {
#       "text": "[1]",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://wp-themes.com/twentytwelve/": {
#       "text": "[2]",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://wp-themes.com/twentythirteen/": {
#       "text": "[3]",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://wp-themes.com/twentyfourteen/": {
#       "text": "[4]",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "http://www.whatwg.org/specs/web-apps/current-work/multipage/links.html#link-type-bookmark": {
#       "text": "[5]",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "http://krijnhoetmer.nl/irc-logs/microformats/20120830#l-128": {
#       "text": "2012-08-30 IRC conversation",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "https://mailpile.pagekite.me:8080/p/Open_Message_Format": {
#       "text": "Mailpile Open Message Format",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "http://indiewebcamp.com": {
#       "text": "indie web camp",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "/wiki/index.php?title=Talk:h-entry&action=edit&redlink=1": {
#       "text": "Discussion",
#       "rels": [
#         "discussion"
#       ],
#       "title": "Discussion about the content page (page does not exist) [t]"
#     },
#     "http://microformats.org": {
#       "text": "Blog",
#       "rels": [
#         "nofollow"
#       ]
#     },
#     "/wiki/Special:RecentChangesLinked/h-entry": {
#       "text": "Related changes",
#       "rels": [
#         "nofollow"
#       ],
#       "title": "Recent changes in pages linked from this page [k]"
#     },
#     "javascript:print();": {
#       "text": "Printable version",
#       "rels": [
#         "alternate"
#       ],
#       "title": "Printable version of this page [p]"
#     }
#   },
#   "debug": {
#     "description": "mf2py - microformats2 parser for python",
#     "source": "https://github.com/microformats/mf2py",
#     "version": "2.0.1",
#     "markup parser": "html5lib"
#   },
#   "alternates": [
#     {
#       "url": "/wiki/index.php?title=Special:RecentChanges&feed=atom",
#       "text": "",
#       "type": "application/atom+xml",
#       "title": "Microformats Wiki Atom feed"
#     },
#     {
#       "url": "javascript:print();",
#       "text": "Printable version",
#       "title": "Printable version of this page [p]"
#     }
#   ]
# }
